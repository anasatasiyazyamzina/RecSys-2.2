# %% [markdown]
# # Surprise library example use

# %% [markdown]
# http://surpriselib.com/

# %%
import pandas as pd

from surprise import Dataset
from surprise import SVD
from surprise import accuracy
from surprise.model_selection import cross_validate

from surprise.model_selection import train_test_split

# %%
data_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.data'
data_df = pd.read_csv(data_path, sep='\t',encoding='ISO-8859-1', header = None)
data_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-60a440a34e1a> in <module>
#       1 data_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.data'
# ----> 2 data_df = pd.read_csv(data_path, sep='\t',encoding='ISO-8859-1', header = None)
#       3 data_df
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1979         if kwds.get("compression") is None and encoding:
#    1980             if isinstance(src, str):
# -> 1981                 src = open(src, "rb")
#    1982                 self.handles.append(src)
#    1983
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ola/.surprise_data/ml-100k/ml-100k/u.data'

# %%
item_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.item'
item_df = pd.read_csv(item_path, sep='|',encoding='ISO-8859-1', header = None)
item_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7aa17583db1b> in <module>
#       1 item_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.item'
# ----> 2 item_df = pd.read_csv(item_path, sep='|',encoding='ISO-8859-1', header = None)
#       3 item_df
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# c:\users\анастасия\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1979         if kwds.get("compression") is None and encoding:
#    1980             if isinstance(src, str):
# -> 1981                 src = open(src, "rb")
#    1982                 self.handles.append(src)
#    1983
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ola/.surprise_data/ml-100k/ml-100k/u.item'

# %% [markdown]
# ### 1. Data loading

# %%
data = Dataset.load_builtin('ml-100k')
data

# %%
trainset, testset = train_test_split(data, test_size=.25)
trainset

# %%
ratings = trainset.all_ratings()

for _ in range (0,5):
    print(next(ratings))
# Out:
# (0, 0, 4.0)
# (0, 323, 4.0)
# (0, 156, 4.0)
# (0, 38, 5.0)
# (0, 146, 5.0)

# %%
testset
# Out:
# [('49', '325', 3.0),
#  ('283', '210', 5.0),
#  ('790', '65', 4.0),
#  ('446', '299', 2.0),
#  ('487', '692', 5.0),
#  ('408', '270', 5.0),
#  ('313', '25', 2.0),
#  ('15', '248', 1.0),
#  ('381', '529', 5.0),
#  ('826', '1091', 3.0),
#  ('872', '748', 3.0),
#  ('429', '226', 3.0),
#  ('937', '301', 1.0),
#  ('328', '327', 3.0),
#  ('184', '521', 4.0),
#  ('638', '96', 4.0),
#  ('561', '91', 4.0),
#  ('699', '596', 3.0),
#  ('313', '235', 3.0),
#  ('144', '963', 4.0),
#  ('221', '186', 4.0),
#  ('654', '736', 5.0),
#  ('70', '208', 4.0),
#  ('406', '573', 3.0),
#  ('290', '31', 4.0),
#  ('389', '95', 3.0),
#  ('343', '408', 5.0),
#  ('276', '748', 3.0),
#  ('18', '949', 3.0),
#  ('690', '722', 3.0),
#  ('652', '748', 3.0),
#  ('934', '427', 4.0),
#  ('53', '156', 4.0),
#  ('616', '322', 4.0),
#  ('880', '210', 4.0),
#  ('480', '479', 4.0),
#  ('694', '205', 5.0),
#  ('286', '42', 4.0),
#  ('886', '214', 3.0),
#  ('313', '490', 4.0),
#  ('87', '182', 4.0),
#  ('490', '50', 5.0),
#  ('447', '206', 4.0),
#  ('230', '680', 4.0),
#  ('262', '132', 3.0),
#  ('378', '796', 2.0),
#  ('531', '323', 5.0),
#  ('537', '687', 1.0),
#  ('380', '121', 3.0),
#  ('537', '11', 3.0),
#  ('500', '755', 3.0),
#  ('579', '1446', 2.0),
#  ('173', '259', 3.0),
#  ('798', '402', 3.0),
#  ('429', '847', 3.0),
#  ('276', '930', 2.0),
#  ('655', '722', 1.0),
#  ('236', '506', 5.0),
#  ('130', '452', 4.0),
#  ('891', '323', 3.0),
#  ('707', '283', 4.0),
#  ('239', '954', 5.0),
#  ('374', '829', 2.0),
#  ('805', '866', 1.0),
#  ('932', '38', 2.0),
#  ('249', '789', 5.0),
#  ('90', '750', 4.0),
#  ('60', '209', 5.0),
#  ('927', '255', 4.0),
#  ('669', '121', 3.0),
#  ('339', '380', 3.0),
#  ('372', '561', 5.0),
#  ('664', '654', 5.0),
#  ('7', '101', 5.0),
#  ('708', '319', 5.0),
#  ('867', '289', 5.0),
#  ('339', '573', 3.0),
#  ('523', '153', 4.0),
#  ('881', '399', 4.0),
#  ('201', '705', 3.0),
#  ('334', '204', 4.0),
#  ('653', '425', 2.0),
#  ('47', '995', 3.0),
#  ('532', '227', 4.0),
#  ('815', '1204', 5.0),
#  ('207', '156', 2.0),
#  ('828', '1062', 4.0),
#  ('848', '42', 2.0),
#  ('363', '1099', 2.0),
#  ('790', '790', 2.0),
#  ('15', '127', 2.0),
#  ('903', '56', 5.0),
#  ('134', '301', 2.0),
#  ('896', '525', 5.0),
#  ('539', '19', 5.0),
#  ('838', '584', 4.0),
#  ('929', '204', 4.0),
#  ('659', '524', 4.0),
#  ('821', '495', 5.0),
#  ('511', '340', 4.0),
#  ('191', '331', 4.0),
#  ('807', '477', 4.0),
#  ('181', '690', 3.0),
#  ('293', '467', 4.0),
#  ('416', '895', 4.0),
#  ('650', '597', 3.0),
#  ('538', '294', 3.0),
#  ('699', '294', 3.0),
#  ('77', '176', 4.0),
#  ('598', '751', 3.0),
#  ('315', '121', 2.0),
#  ('380', '183', 4.0),
#  ('825', '148', 4.0),
#  ('345', '1281', 4.0),
#  ('389', '1119', 3.0),
#  ('554', '229', 3.0),
#  ('207', '540', 3.0),
#  ('883', '147', 2.0),
#  ('747', '835', 3.0),
#  ('864', '625', 4.0),
#  ('664', '70', 3.0),
#  ('488', '198', 4.0),
#  ('95', '385', 4.0),
#  ('655', '396', 2.0),
#  ('451', '879', 4.0),
#  ('887', '91', 5.0),
#  ('529', '309', 3.0),
#  ('682', '56', 4.0),
#  ('113', '303', 5.0),
#  ('572', '284', 3.0),
#  ('655', '594', 3.0),
#  ('10', '527', 4.0),
#  ('640', '750', 5.0),
#  ('291', '672', 3.0),
#  ('503', '402', 3.0),
#  ('276', '432', 5.0),
#  ('102', '720', 2.0),
#  ('497', '588', 4.0),
#  ('207', '233', 3.0),
#  ('417', '3', 4.0),
#  ('506', '239', 3.0),
#  ('6', '127', 5.0),
#  ('345', '1221', 3.0),
#  ('267', '239', 4.0),
#  ('222', '446', 3.0),
#  ('815', '252', 2.0),
#  ('533', '742', 4.0),
#  ('897', '186', 5.0),
#  ('889', '182', 4.0),
#  ('193', '301', 4.0),
#  ('42', '282', 4.0),
#  ('290', '181', 5.0),
#  ('276', '392', 3.0),
#  ('342', '248', 3.0),
#  ('453', '298', 4.0),
#  ('887', '710', 5.0),
#  ('405', '142', 1.0),
#  ('506', '655', 4.0),
#  ('198', '684', 3.0),
#  ('10', '155', 4.0),
#  ('8', '188', 5.0),
#  ('903', '48', 4.0),
#  ('224', '731', 4.0),
#  ('537', '642', 4.0),
#  ('328', '70', 4.0),
#  ('406', '1267', 3.0),
#  ('303', '293', 4.0),
#  ('187', '792', 5.0),
#  ('560', '654', 5.0),
#  ('450', '477', 4.0),
#  ('174', '268', 5.0),
#  ('145', '692', 2.0),
#  ('710', '92', 3.0),
#  ('846', '183', 4.0),
#  ('293', '27', 3.0),
#  ('615', '283', 4.0),
#  ('582', '300', 3.0),
#  ('435', '171', 5.0),
#  ('261', '117', 4.0),
#  ('516', '181', 4.0),
#  ('766', '198', 4.0),
#  ('659', '134', 4.0),
#  ('532', '1226', 4.0),
#  ('152', '692', 5.0),
#  ('615', '269', 4.0),
#  ('224', '1381', 3.0),
#  ('414', '100', 5.0),
#  ('197', '190', 3.0),
#  ('313', '663', 5.0),
#  ('134', '539', 4.0),
#  ('782', '1405', 2.0),
#  ('778', '94', 2.0),
#  ('497', '1210', 4.0),
#  ('452', '510', 4.0),
#  ('296', '248', 5.0),
#  ('43', '114', 5.0),
#  ('158', '809', 3.0),
#  ('405', '67', 5.0),
#  ('119', '526', 2.0),
#  ('189', '525', 5.0),
#  ('618', '28', 4.0),
#  ('349', '126', 2.0),
#  ('243', '221', 5.0),
#  ('902', '306', 4.0),
#  ('399', '84', 2.0),
#  ('332', '50', 5.0),
#  ('643', '956', 4.0),
#  ('161', '197', 3.0),
#  ('293', '200', 4.0),
#  ('852', '100', 4.0),
#  ('878', '732', 4.0),
#  ('749', '23', 3.0),
#  ('846', '738', 4.0),
#  ('151', '627', 2.0),
#  ('450', '131', 4.0),
#  ('887', '477', 1.0),
#  ('14', '382', 5.0),
#  ('606', '620', 4.0),
#  ('327', '275', 4.0),
#  ('472', '49', 5.0),
#  ('174', '269', 5.0),
#  ('543', '237', 4.0),
#  ('201', '406', 1.0),
#  ('385', '919', 4.0),
#  ('64', '161', 3.0),
#  ('151', '638', 5.0),
#  ('38', '122', 1.0),
#  ('227', '244', 3.0),
#  ('417', '248', 4.0),
#  ('210', '404', 5.0),
#  ('465', '109', 3.0),
#  ('130', '1215', 2.0),
#  ('454', '22', 4.0),
#  ('619', '187', 5.0),
#  ('921', '313', 5.0),
#  ('72', '628', 4.0),
#  ('659', '448', 4.0),
#  ('732', '321', 3.0),
#  ('452', '475', 2.0),
#  ('268', '248', 3.0),
#  ('819', '268', 4.0),
#  ('566', '163', 5.0),
#  ('124', '79', 3.0),
#  ('923', '333', 5.0),
#  ('481', '663', 4.0),
#  ('312', '208', 5.0),
#  ('151', '1', 5.0),
#  ('744', '127', 5.0),
#  ('308', '129', 5.0),
#  ('474', '288', 3.0),
#  ('601', '1039', 4.0),
#  ('82', '475', 1.0),
#  ('286', '290', 3.0),
#  ('655', '781', 1.0),
#  ('225', '194', 5.0),
#  ('922', '699', 3.0),
#  ('943', '393', 2.0),
#  ('417', '628', 3.0),
#  ('591', '1017', 3.0),
#  ('94', '223', 5.0),
#  ('445', '831', 1.0),
#  ('54', '24', 1.0),
#  ('327', '42', 3.0),
#  ('474', '357', 5.0),
#  ('493', '298', 3.0),
#  ('406', '174', 4.0),
#  ('18', '631', 5.0),
#  ('442', '986', 1.0),
#  ('321', '498', 5.0),
#  ('698', '435', 3.0),
#  ('401', '65', 4.0),
#  ('291', '790', 4.0),
#  ('871', '1345', 3.0),
#  ('303', '426', 3.0),
#  ('573', '519', 4.0),
#  ('551', '505', 5.0),
#  ('327', '718', 4.0),
#  ('885', '1030', 1.0),
#  ('694', '449', 4.0),
#  ('790', '577', 2.0),
#  ('283', '95', 5.0),
#  ('279', '1240', 1.0),
#  ('873', '258', 3.0),
#  ('95', '143', 4.0),
#  ('619', '55', 1.0),
#  ('892', '69', 5.0),
#  ('332', '332', 4.0),
#  ('556', '170', 4.0),
#  ('383', '180', 5.0),
#  ('587', '323', 4.0),
#  ('802', '200', 4.0),
#  ('514', '13', 3.0),
#  ('835', '257', 3.0),
#  ('870', '276', 4.0),
#  ('690', '63', 3.0),
#  ('504', '257', 5.0),
#  ('33', '880', 3.0),
#  ('592', '238', 5.0),
#  ('246', '470', 4.0),
#  ('661', '514', 3.0),
#  ('425', '252', 2.0),
#  ('536', '380', 4.0),
#  ('144', '1016', 3.0),
#  ('608', '58', 2.0),
#  ('45', '225', 4.0),
#  ('92', '566', 4.0),
#  ('331', '178', 3.0),
#  ('401', '501', 2.0),
#  ('358', '179', 4.0),
#  ('862', '982', 4.0),
#  ('299', '724', 3.0),
#  ('291', '420', 4.0),
#  ('790', '29', 2.0),
#  ('554', '69', 5.0),
#  ('110', '385', 3.0),
#  ('44', '450', 2.0),
#  ('325', '200', 2.0),
#  ('804', '97', 4.0),
#  ('299', '730', 4.0),
#  ('382', '100', 4.0),
#  ('536', '73', 4.0),
#  ('721', '527', 5.0),
#  ('18', '381', 4.0),
#  ('361', '611', 4.0),
#  ('189', '174', 5.0),
#  ('296', '514', 5.0),
#  ('354', '13', 3.0),
#  ('627', '187', 5.0),
#  ('381', '682', 2.0),
#  ('865', '7', 5.0),
#  ('130', '168', 3.0),
#  ('63', '137', 4.0),
#  ('59', '1047', 2.0),
#  ('648', '1060', 2.0),
#  ('716', '428', 3.0),
#  ('437', '812', 3.0),
#  ('13', '912', 2.0),
#  ('551', '1087', 1.0),
#  ('336', '790', 2.0),
#  ('305', '960', 1.0),
#  ('622', '725', 3.0),
#  ('543', '684', 4.0),
#  ('85', '1103', 3.0),
#  ('609', '313', 5.0),
#  ('781', '324', 4.0),
#  ('479', '274', 4.0),
#  ('254', '498', 4.0),
#  ('709', '379', 3.0),
#  ('540', '50', 5.0),
#  ('682', '95', 5.0),
#  ('291', '1178', 4.0),
#  ('1', '148', 2.0),
#  ('683', '289', 4.0),
#  ('543', '531', 4.0),
#  ('795', '826', 3.0),
#  ('699', '683', 3.0),
#  ('627', '64', 5.0),
#  ('22', '172', 4.0),
#  ('450', '221', 4.0),
#  ('807', '418', 4.0),
#  ('842', '340', 5.0),
#  ('274', '744', 5.0),
#  ('262', '44', 2.0),
#  ('1', '35', 1.0),
#  ('312', '525', 5.0),
#  ('447', '248', 5.0),
#  ('466', '127', 3.0),
#  ('296', '22', 4.0),
#  ('624', '544', 4.0),
#  ('622', '1552', 2.0),
#  ('425', '669', 3.0),
#  ('932', '491', 5.0),
#  ('246', '385', 1.0),
#  ('758', '364', 4.0),
#  ('846', '675', 2.0),
#  ('379', '192', 4.0),
#  ('870', '479', 5.0),
#  ('778', '780', 3.0),
#  ('474', '291', 4.0),
#  ('497', '810', 3.0),
#  ('95', '102', 4.0),
#  ('655', '775', 2.0),
#  ('198', '64', 4.0),
#  ('327', '1012', 2.0),
#  ('881', '392', 5.0),
#  ('417', '117', 4.0),
#  ('788', '300', 5.0),
#  ('43', '283', 2.0),
#  ('57', '496', 4.0),
#  ('36', '333', 4.0),
#  ('682', '699', 3.0),
#  ('892', '144', 5.0),
#  ('169', '429', 3.0),
#  ('500', '514', 5.0),
#  ('59', '951', 3.0),
#  ('234', '165', 5.0),
#  ('758', '527', 5.0),
#  ('11', '229', 4.0),
#  ('399', '96', 3.0),
#  ('211', '127', 4.0),
#  ('686', '451', 4.0),
#  ('766', '527', 5.0),
#  ('416', '447', 4.0),
#  ('541', '222', 4.0),
#  ('655', '113', 3.0),
#  ('63', '250', 5.0),
#  ('846', '615', 5.0),
#  ('380', '356', 2.0),
#  ('407', '519', 4.0),
#  ('472', '227', 5.0),
#  ('924', '318', 5.0),
#  ('742', '546', 1.0),
#  ('13', '807', 1.0),
#  ('312', '190', 5.0),
#  ('796', '178', 3.0),
#  ('330', '739', 5.0),
#  ('181', '1346', 1.0),
#  ('763', '357', 4.0),
#  ('559', '204', 3.0),
#  ('249', '546', 3.0),
#  ('50', '325', 1.0),
#  ('371', '183', 5.0),
#  ('643', '521', 4.0),
#  ('342', '410', 3.0),
#  ('601', '1047', 1.0),
#  ('178', '98', 5.0),
#  ('437', '319', 5.0),
#  ('269', '55', 4.0),
#  ('747', '135', 5.0),
#  ('435', '185', 4.0),
#  ('702', '294', 1.0),
#  ('416', '56', 5.0),
#  ('358', '511', 2.0),
#  ('503', '121', 3.0),
#  ('233', '614', 4.0),
#  ('187', '65', 5.0),
#  ('897', '185', 5.0),
#  ('393', '136', 5.0),
#  ('586', '182', 3.0),
#  ('190', '300', 4.0),
#  ('6', '9', 4.0),
#  ('887', '969', 5.0),
#  ('648', '22', 4.0),
#  ('244', '941', 4.0),
#  ('737', '175', 5.0),
#  ('466', '210', 4.0),
#  ('653', '696', 1.0),
#  ('141', '407', 2.0),
#  ('222', '1044', 4.0),
#  ('796', '487', 5.0),
#  ('422', '458', 3.0),
#  ('301', '333', 4.0),
#  ('361', '226', 3.0),
#  ('541', '62', 4.0),
#  ('776', '318', 4.0),
#  ('471', '946', 2.0),
#  ('45', '118', 4.0),
#  ('454', '147', 3.0),
#  ('886', '1324', 2.0),
#  ('868', '73', 1.0),
#  ('181', '683', 1.0),
#  ('330', '204', 5.0),
#  ('93', '412', 2.0),
#  ('499', '300', 4.0),
#  ('350', '210', 4.0),
#  ('332', '9', 4.0),
#  ('393', '725', 2.0),
#  ('518', '544', 3.0),
#  ('887', '122', 5.0),
#  ('654', '1285', 4.0),
#  ('537', '591', 3.0),
#  ('311', '623', 2.0),
#  ('455', '234', 4.0),
#  ('294', '689', 3.0),
#  ('716', '199', 4.0),
#  ('624', '346', 3.0),
#  ('160', '209', 4.0),
#  ('640', '338', 5.0),
#  ('95', '195', 5.0),
#  ('413', '9', 4.0),
#  ('889', '175', 4.0),
#  ('126', '315', 4.0),
#  ('315', '651', 3.0),
#  ('943', '415', 1.0),
#  ('305', '655', 4.0),
#  ('145', '713', 4.0),
#  ('449', '251', 3.0),
#  ('747', '634', 5.0),
#  ('110', '1228', 3.0),
#  ('82', '25', 2.0),
#  ('254', '457', 2.0),
#  ('428', '344', 3.0),
#  ('725', '9', 4.0),
#  ('805', '942', 3.0),
#  ('294', '1245', 3.0),
#  ('796', '448', 4.0),
#  ('588', '729', 3.0),
#  ('886', '216', 5.0),
#  ('883', '367', 5.0),
#  ('87', '201', 2.0),
#  ('235', '1193', 4.0),
#  ('526', '250', 2.0),
#  ('472', '222', 5.0),
#  ('7', '421', 3.0),
#  ('145', '930', 2.0),
#  ('358', '208', 2.0),
#  ('428', '271', 2.0),
#  ('495', '451', 4.0),
#  ('445', '118', 2.0),
#  ('796', '525', 4.0),
#  ('660', '161', 1.0),
#  ('479', '535', 3.0),
#  ('539', '660', 5.0),
#  ('327', '523', 4.0),
#  ('145', '185', 4.0),
#  ('334', '537', 4.0),
#  ('61', '269', 3.0),
#  ('883', '550', 3.0),
#  ('265', '934', 3.0),
#  ('754', '127', 4.0),
#  ('524', '419', 1.0),
#  ('192', '287', 4.0),
#  ('552', '125', 3.0),
#  ('500', '258', 4.0),
#  ('896', '172', 5.0),
#  ('597', '713', 2.0),
#  ('661', '751', 4.0),
#  ('886', '56', 4.0),
#  ('58', '7', 5.0),
#  ('223', '930', 2.0),
#  ('222', '815', 2.0),
#  ('216', '172', 4.0),
#  ('213', '31', 4.0),
#  ('932', '755', 2.0),
#  ('533', '13', 3.0),
#  ('234', '488', 4.0),
#  ('405', '574', 1.0),
#  ('92', '22', 3.0),
#  ('493', '423', 2.0),
#  ('92', '63', 3.0),
#  ('687', '268', 5.0),
#  ('889', '483', 4.0),
#  ('59', '204', 5.0),
#  ('927', '195', 4.0),
#  ('189', '120', 1.0),
#  ('604', '670', 5.0),
#  ('496', '484', 3.0),
#  ('738', '258', 4.0),
#  ('790', '436', 4.0),
#  ('854', '11', 5.0),
#  ('269', '188', 2.0),
#  ('99', '182', 4.0),
#  ('478', '673', 3.0),
#  ('592', '483', 5.0),
#  ('331', '947', 5.0),
#  ('239', '12', 5.0),
#  ('234', '186', 3.0),
#  ('567', '177', 4.0),
#  ('345', '639', 4.0),
#  ('570', '326', 1.0),
#  ('248', '7', 2.0),
#  ('279', '165', 4.0),
#  ('556', '325', 2.0),
#  ('582', '293', 5.0),
#  ('49', '590', 1.0),
#  ('394', '720', 2.0),
#  ('249', '658', 4.0),
#  ('56', '1047', 4.0),
#  ('655', '279', 3.0),
#  ('354', '629', 3.0),
#  ('10', '589', 5.0),
#  ('916', '238', 4.0),
#  ('578', '380', 3.0),
#  ('48', '988', 2.0),
#  ('87', '423', 3.0),
#  ('727', '154', 3.0),
#  ('504', '68', 5.0),
#  ('686', '11', 4.0),
#  ('586', '68', 4.0),
#  ('666', '510', 4.0),
#  ('28', '568', 4.0),
#  ('486', '285', 5.0),
#  ('889', '455', 4.0),
#  ('479', '748', 3.0),
#  ('179', '331', 2.0),
#  ('252', '149', 5.0),
#  ('189', '199', 5.0),
#  ('334', '69', 1.0),
#  ('886', '761', 4.0),
#  ('46', '307', 3.0),
#  ('606', '951', 2.0),
#  ('327', '709', 4.0),
#  ('449', '170', 4.0),
#  ('601', '64', 4.0),
#  ('151', '1269', 5.0),
#  ('655', '36', 2.0),
#  ('777', '690', 4.0),
#  ('807', '679', 4.0),
#  ('716', '527', 5.0),
#  ('416', '717', 2.0),
#  ('378', '110', 3.0),
#  ('401', '11', 2.0),
#  ('458', '234', 4.0),
#  ('524', '304', 4.0),
#  ('175', '132', 3.0),
#  ('353', '271', 2.0),
#  ('518', '1047', 4.0),
#  ('210', '956', 3.0),
#  ('907', '740', 5.0),
#  ('537', '510', 3.0),
#  ('507', '827', 5.0),
#  ('899', '250', 2.0),
#  ('932', '489', 4.0),
#  ('640', '302', 5.0),
#  ('532', '44', 5.0),
#  ('774', '105', 1.0),
#  ('111', '303', 3.0),
#  ('423', '282', 4.0),
#  ('763', '960', 4.0),
#  ('369', '271', 5.0),
#  ('298', '523', 4.0),
#  ('184', '287', 4.0),
#  ('115', '763', 2.0),
#  ('896', '942', 4.0),
#  ('508', '239', 2.0),
#  ('91', '435', 4.0),
#  ('504', '1093', 1.0),
#  ('871', '300', 4.0),
#  ('26', '926', 2.0),
#  ('145', '176', 5.0),
#  ('717', '405', 3.0),
#  ('823', '721', 4.0),
#  ('538', '234', 3.0),
#  ('277', '1011', 3.0),
#  ('145', '993', 3.0),
#  ('195', '242', 4.0),
#  ('145', '413', 3.0),
#  ('542', '121', 2.0),
#  ('932', '528', 5.0),
#  ('660', '175', 3.0),
#  ('401', '312', 3.0),
#  ('266', '319', 2.0),
#  ('642', '49', 4.0),
#  ('588', '97', 2.0),
#  ('823', '240', 3.0),
#  ('42', '239', 5.0),
#  ('871', '690', 3.0),
#  ('292', '203', 4.0),
#  ('332', '879', 4.0),
#  ('234', '959', 2.0),
#  ('178', '619', 3.0),
#  ('936', '111', 4.0),
#  ('847', '1050', 3.0),
#  ('908', '414', 3.0),
#  ('240', '313', 5.0),
#  ('543', '98', 4.0),
#  ('937', '50', 5.0),
#  ('314', '1057', 2.0),
#  ('222', '248', 4.0),
#  ('194', '523', 5.0),
#  ('889', '1589', 5.0),
#  ('774', '176', 4.0),
#  ('845', '242', 4.0),
#  ('566', '405', 5.0),
#  ('358', '639', 4.0),
#  ('178', '873', 3.0),
#  ('774', '23', 3.0),
#  ('927', '158', 2.0),
#  ('181', '1381', 2.0),
#  ('606', '161', 4.0),
#  ('83', '832', 3.0),
#  ('128', '215', 3.0),
#  ('889', '540', 2.0),
#  ('855', '475', 4.0),
#  ('178', '1038', 2.0),
#  ('69', '886', 4.0),
#  ('932', '183', 4.0),
#  ('399', '48', 3.0),
#  ('151', '1039', 4.0),
#  ('416', '864', 3.0),
#  ('682', '713', 3.0),
#  ('72', '38', 3.0),
#  ('399', '559', 3.0),
#  ('487', '140', 3.0),
#  ('846', '317', 3.0),
#  ('383', '315', 5.0),
#  ('130', '188', 4.0),
#  ('551', '291', 4.0),
#  ('782', '936', 3.0),
#  ('311', '1119', 4.0),
#  ('618', '73', 3.0),
#  ('365', '309', 1.0),
#  ('314', '393', 4.0),
#  ('456', '1248', 3.0),
#  ('407', '152', 4.0),
#  ('788', '621', 3.0),
#  ('119', '449', 5.0),
#  ('22', '238', 5.0),
#  ('326', '566', 4.0),
#  ('500', '244', 3.0),
#  ('823', '710', 4.0),
#  ('389', '118', 2.0),
#  ('862', '483', 5.0),
#  ('597', '242', 4.0),
#  ('741', '790', 3.0),
#  ('246', '1135', 1.0),
#  ('897', '742', 3.0),
#  ('249', '294', 3.0),
#  ('840', '143', 4.0),
#  ('13', '116', 5.0),
#  ('224', '555', 3.0),
#  ('906', '100', 4.0),
#  ('648', '781', 4.0),
#  ('189', '253', 4.0),
#  ('694', '528', 3.0),
#  ('223', '318', 4.0),
#  ('710', '510', 4.0),
#  ('42', '96', 5.0),
#  ('675', '1255', 1.0),
#  ('588', '71', 4.0),
#  ('496', '559', 5.0),
#  ('645', '1018', 3.0),
#  ('592', '514', 5.0),
#  ('159', '877', 3.0),
#  ('405', '177', 1.0),
#  ('534', '121', 4.0),
#  ('351', '286', 5.0),
#  ('399', '237', 3.0),
#  ('318', '301', 4.0),
#  ('933', '424', 1.0),
#  ('642', '627', 3.0),
#  ('536', '222', 4.0),
#  ('214', '213', 4.0),
#  ('291', '95', 4.0),
#  ('435', '710', 4.0),
#  ('457', '386', 3.0),
#  ('373', '499', 4.0),
#  ('389', '53', 2.0),
#  ('336', '282', 3.0),
#  ('933', '569', 1.0),
#  ('56', '68', 3.0),
#  ('545', '746', 4.0),
#  ('836', '507', 4.0),
#  ('642', '40', 4.0),
#  ('254', '229', 4.0),
#  ('642', '451', 5.0),
#  ('7', '215', 4.0),
#  ('586', '121', 5.0),
#  ('222', '654', 3.0),
#  ('852', '50', 5.0),
#  ('545', '684', 4.0),
#  ('838', '187', 3.0),
#  ('286', '176', 4.0),
#  ('932', '447', 3.0),
#  ('343', '48', 3.0),
#  ('18', '212', 5.0),
#  ('293', '156', 4.0),
#  ('894', '246', 4.0),
#  ('387', '230', 3.0),
#  ('694', '490', 4.0),
#  ('655', '715', 3.0),
#  ('49', '627', 2.0),
#  ('840', '185', 5.0),
#  ('389', '1036', 2.0),
#  ('452', '614', 3.0),
#  ('489', '307', 4.0),
#  ('608', '213', 4.0),
#  ('63', '924', 3.0),
#  ('834', '405', 4.0),
#  ('116', '539', 2.0),
#  ('141', '121', 4.0),
#  ('412', '169', 4.0),
#  ('156', '646', 4.0),
#  ('316', '289', 2.0),
#  ('551', '346', 4.0),
#  ('682', '578', 3.0),
#  ('524', '499', 4.0),
#  ('717', '333', 4.0),
#  ('116', '879', 2.0),
#  ('748', '153', 4.0),
#  ('222', '373', 3.0),
#  ('664', '792', 4.0),
#  ('689', '237', 3.0),
#  ('102', '1', 3.0),
#  ('868', '455', 5.0),
#  ('603', '1483', 5.0),
#  ('334', '433', 5.0),
#  ('90', '889', 3.0),
#  ('429', '729', 2.0),
#  ('531', '908', 1.0),
#  ('151', '654', 4.0),
#  ('923', '105', 4.0),
#  ('496', '652', 5.0),
#  ('737', '127', 5.0),
#  ('416', '265', 5.0),
#  ('445', '1067', 1.0),
#  ('722', '476', 4.0),
#  ('716', '197', 5.0),
#  ('298', '118', 4.0),
#  ('629', '328', 3.0),
#  ('276', '691', 4.0),
#  ('379', '704', 3.0),
#  ('881', '98', 5.0),
#  ('916', '317', 4.0),
#  ('526', '332', 2.0),
#  ('664', '73', 2.0),
#  ('18', '242', 5.0),
#  ('487', '239', 5.0),
#  ('403', '151', 4.0),
#  ('87', '722', 4.0),
#  ('903', '118', 4.0),
#  ('264', '1355', 4.0),
#  ('846', '419', 5.0),
#  ('882', '929', 1.0),
#  ('354', '283', 4.0),
#  ('18', '48', 4.0),
#  ('642', '470', 4.0),
#  ('709', '164', 3.0),
#  ('301', '162', 3.0),
#  ('14', '211', 4.0),
#  ('60', '650', 4.0),
#  ('838', '181', 5.0),
#  ('380', '97', 3.0),
#  ('365', '352', 1.0),
#  ('713', '1431', 3.0),
#  ('56', '7', 5.0),
#  ('82', '504', 4.0),
#  ('64', '209', 5.0),
#  ('205', '289', 4.0),
#  ('72', '172', 1.0),
#  ('655', '43', 3.0),
#  ('788', '566', 4.0),
#  ('83', '820', 2.0),
#  ('525', '1', 4.0),
#  ('381', '259', 2.0),
#  ('498', '480', 5.0),
#  ('724', '245', 2.0),
#  ('798', '1337', 3.0),
#  ('761', '9', 2.0),
#  ('200', '609', 3.0),
#  ('901', '739', 5.0),
#  ('191', '891', 3.0),
#  ('784', '326', 5.0),
#  ('122', '464', 5.0),
#  ('366', '218', 3.0),
#  ('343', '68', 1.0),
#  ('602', '259', 4.0),
#  ('881', '183', 4.0),
#  ('489', '876', 2.0),
#  ('380', '573', 1.0),
#  ('472', '375', 5.0),
#  ('455', '20', 3.0),
#  ('405', '1184', 1.0),
#  ('682', '728', 3.0),
#  ('630', '322', 3.0),
#  ('557', '165', 5.0),
#  ('256', '222', 4.0),
#  ('699', '321', 3.0),
#  ('608', '961', 4.0),
#  ('407', '185', 5.0),
#  ('65', '427', 5.0),
#  ('916', '684', 3.0),
#  ('523', '949', 5.0),
#  ('287', '952', 4.0),
#  ('389', '820', 3.0),
#  ('264', '173', 5.0),
#  ('1', '176', 5.0),
#  ('217', '685', 5.0),
#  ('704', '480', 5.0),
#  ('445', '689', 1.0),
#  ('311', '98', 5.0),
#  ('943', '403', 4.0),
#  ('311', '183', 5.0),
#  ('181', '1129', 1.0),
#  ('429', '231', 2.0),
#  ('853', '879', 4.0),
#  ('262', '955', 2.0),
#  ('130', '79', 5.0),
#  ('297', '198', 3.0),
#  ('816', '271', 4.0),
#  ('807', '265', 5.0),
#  ('318', '210', 4.0),
#  ('437', '969', 4.0),
#  ('263', '732', 5.0),
#  ('24', '727', 3.0),
#  ('645', '92', 3.0),
#  ('638', '226', 5.0),
#  ('401', '111', 4.0),
#  ('325', '647', 5.0),
#  ('679', '721', 3.0),
#  ('917', '879', 2.0),
#  ('376', '197', 4.0),
#  ('864', '225', 3.0),
#  ('405', '1306', 1.0),
#  ('216', '169', 3.0),
#  ('455', '455', 3.0),
#  ('669', '276', 2.0),
#  ('389', '674', 2.0),
#  ('580', '25', 3.0),
#  ('288', '136', 5.0),
#  ('218', '642', 3.0),
#  ('768', '762', 1.0),
#  ('71', '134', 3.0),
#  ('790', '403', 4.0),
#  ('864', '169', 5.0),
#  ('224', '591', 3.0),
#  ('470', '248', 3.0),
#  ('452', '924', 5.0),
#  ('406', '22', 3.0),
#  ('472', '288', 5.0),
#  ('878', '140', 2.0),
#  ('474', '1063', 5.0),
#  ('757', '576', 3.0),
#  ('331', '305', 5.0),
#  ('7', '488', 4.0),
#  ('407', '388', 2.0),
#  ('339', '9', 5.0),
#  ('470', '288', 4.0),
#  ('572', '289', 3.0),
#  ('803', '306', 4.0),
#  ('286', '234', 3.0),
#  ('864', '561', 4.0),
#  ('57', '710', 3.0),
#  ('815', '434', 3.0),
#  ('167', '216', 4.0),
#  ('774', '178', 4.0),
#  ('44', '56', 2.0),
#  ('723', '164', 4.0),
#  ('6', '59', 5.0),
#  ('788', '70', 4.0),
#  ('178', '655', 4.0),
#  ('311', '39', 4.0),
#  ('696', '313', 3.0),
#  ('328', '405', 4.0),
#  ('60', '659', 4.0),
#  ('619', '346', 3.0),
#  ('416', '257', 3.0),
#  ('429', '21', 2.0),
#  ('832', '471', 4.0),
#  ('823', '217', 3.0),
#  ('896', '1672', 2.0),
#  ('661', '175', 2.0),
#  ('246', '1052', 1.0),
#  ('496', '727', 5.0),
#  ('91', '612', 4.0),
#  ('751', '428', 4.0),
#  ('897', '826', 4.0),
#  ('551', '475', 5.0),
#  ('265', '15', 3.0),
#  ('550', '255', 3.0),
#  ('727', '89', 5.0),
#  ('246', '930', 2.0),
#  ('82', '218', 3.0),
#  ('452', '659', 4.0),
#  ('365', '25', 4.0),
#  ('941', '993', 4.0),
#  ('474', '234', 5.0),
#  ('650', '432', 4.0),
#  ('269', '476', 1.0),
#  ('561', '1024', 3.0),
#  ('753', '484', 5.0),
#  ('653', '87', 4.0),
#  ('766', '965', 3.0),
#  ('862', '210', 4.0),
#  ('393', '271', 3.0),
#  ('406', '503', 3.0),
#  ('618', '790', 3.0),
#  ('222', '162', 2.0),
#  ('374', '68', 1.0),
#  ('889', '686', 3.0),
#  ('426', '653', 4.0),
#  ('405', '627', 1.0),
#  ('881', '192', 5.0),
#  ('885', '356', 3.0),
#  ('817', '289', 2.0),
#  ('455', '191', 5.0),
#  ('537', '455', 1.0),
#  ('99', '315', 4.0),
#  ('314', '693', 3.0),
#  ('659', '62', 4.0),
#  ('822', '333', 4.0),
#  ('886', '959', 3.0),
#  ('638', '222', 4.0),
#  ('617', '497', 3.0),
#  ('484', '70', 5.0),
#  ('785', '294', 4.0),
#  ('870', '856', 3.0),
#  ('918', '208', 3.0),
#  ('472', '385', 5.0),
#  ('532', '204', 5.0),
#  ('181', '1025', 1.0),
#  ('665', '472', 3.0),
#  ('188', '717', 4.0),
#  ('417', '203', 4.0),
#  ('468', '39', 3.0),
#  ('180', '56', 5.0),
#  ('766', '648', 3.0),
#  ('295', '73', 4.0),
#  ('130', '366', 5.0),
#  ('16', '208', 5.0),
#  ...]

# %% [markdown]
# ### 2. Training

# %%
algo = SVD()

algo.fit(trainset)

# %% [markdown]
# ### 3. Testing and evaluation

# %%
predictions = algo.test(testset)

predictions
# Out:
# [Prediction(uid='49', iid='325', r_ui=3.0, est=1.6098380082812922, details={'was_impossible': False}),
#  Prediction(uid='283', iid='210', r_ui=5.0, est=4.35649459976755, details={'was_impossible': False}),
#  Prediction(uid='790', iid='65', r_ui=4.0, est=3.428360718543323, details={'was_impossible': False}),
#  Prediction(uid='446', iid='299', r_ui=2.0, est=2.706015166330745, details={'was_impossible': False}),
#  Prediction(uid='487', iid='692', r_ui=5.0, est=4.21058836872263, details={'was_impossible': False}),
#  Prediction(uid='408', iid='270', r_ui=5.0, est=3.9649062926838377, details={'was_impossible': False}),
#  Prediction(uid='313', iid='25', r_ui=2.0, est=3.6692100359172244, details={'was_impossible': False}),
#  Prediction(uid='15', iid='248', r_ui=1.0, est=3.175675161194365, details={'was_impossible': False}),
#  Prediction(uid='381', iid='529', r_ui=5.0, est=3.878864622512205, details={'was_impossible': False}),
#  Prediction(uid='826', iid='1091', r_ui=3.0, est=3.227445821249438, details={'was_impossible': False}),
#  Prediction(uid='872', iid='748', r_ui=3.0, est=3.1881263176568004, details={'was_impossible': False}),
#  Prediction(uid='429', iid='226', r_ui=3.0, est=3.0637213391384717, details={'was_impossible': False}),
#  Prediction(uid='937', iid='301', r_ui=1.0, est=3.042982514698474, details={'was_impossible': False}),
#  Prediction(uid='328', iid='327', r_ui=3.0, est=3.0543866271930504, details={'was_impossible': False}),
#  Prediction(uid='184', iid='521', r_ui=4.0, est=4.073231955951713, details={'was_impossible': False}),
#  Prediction(uid='638', iid='96', r_ui=4.0, est=3.8888015130825213, details={'was_impossible': False}),
#  Prediction(uid='561', iid='91', r_ui=4.0, est=3.07449173155213, details={'was_impossible': False}),
#  Prediction(uid='699', iid='596', r_ui=3.0, est=3.203480991597834, details={'was_impossible': False}),
#  Prediction(uid='313', iid='235', r_ui=3.0, est=2.452810101450825, details={'was_impossible': False}),
#  Prediction(uid='144', iid='963', r_ui=4.0, est=4.312570433711327, details={'was_impossible': False}),
#  Prediction(uid='221', iid='186', r_ui=4.0, est=4.142977557800443, details={'was_impossible': False}),
#  Prediction(uid='654', iid='736', r_ui=5.0, est=3.7988092518937586, details={'was_impossible': False}),
#  Prediction(uid='70', iid='208', r_ui=4.0, est=3.7855772384129187, details={'was_impossible': False}),
#  Prediction(uid='406', iid='573', r_ui=3.0, est=2.8977564009212737, details={'was_impossible': False}),
#  Prediction(uid='290', iid='31', r_ui=4.0, est=3.3600617285478327, details={'was_impossible': False}),
#  Prediction(uid='389', iid='95', r_ui=3.0, est=3.7322284636170657, details={'was_impossible': False}),
#  Prediction(uid='343', iid='408', r_ui=5.0, est=4.777230408247835, details={'was_impossible': False}),
#  Prediction(uid='276', iid='748', r_ui=3.0, est=3.01702954741276, details={'was_impossible': False}),
#  Prediction(uid='18', iid='949', r_ui=3.0, est=3.4579750649805954, details={'was_impossible': False}),
#  Prediction(uid='690', iid='722', r_ui=3.0, est=2.7258323565416176, details={'was_impossible': False}),
#  Prediction(uid='652', iid='748', r_ui=3.0, est=3.0462918087148942, details={'was_impossible': False}),
#  Prediction(uid='934', iid='427', r_ui=4.0, est=4.581363747288672, details={'was_impossible': False}),
#  Prediction(uid='53', iid='156', r_ui=4.0, est=3.986005671508489, details={'was_impossible': False}),
#  Prediction(uid='616', iid='322', r_ui=4.0, est=3.313398370829607, details={'was_impossible': False}),
#  Prediction(uid='880', iid='210', r_ui=4.0, est=4.391126563796836, details={'was_impossible': False}),
#  Prediction(uid='480', iid='479', r_ui=4.0, est=3.956809072367014, details={'was_impossible': False}),
#  Prediction(uid='694', iid='205', r_ui=5.0, est=4.308084793617619, details={'was_impossible': False}),
#  Prediction(uid='286', iid='42', r_ui=4.0, est=4.0154656084085385, details={'was_impossible': False}),
#  Prediction(uid='886', iid='214', r_ui=3.0, est=3.132431353193686, details={'was_impossible': False}),
#  Prediction(uid='313', iid='490', r_ui=4.0, est=4.029472755938403, details={'was_impossible': False}),
#  Prediction(uid='87', iid='182', r_ui=4.0, est=4.26053694265949, details={'was_impossible': False}),
#  Prediction(uid='490', iid='50', r_ui=5.0, est=3.3969059401584953, details={'was_impossible': False}),
#  Prediction(uid='447', iid='206', r_ui=4.0, est=3.4222296790115396, details={'was_impossible': False}),
#  Prediction(uid='230', iid='680', r_ui=4.0, est=2.879511976205326, details={'was_impossible': False}),
#  Prediction(uid='262', iid='132', r_ui=3.0, est=3.833089982469225, details={'was_impossible': False}),
#  Prediction(uid='378', iid='796', r_ui=2.0, est=3.2927014975510054, details={'was_impossible': False}),
#  Prediction(uid='531', iid='323', r_ui=5.0, est=3.125536995774815, details={'was_impossible': False}),
#  Prediction(uid='537', iid='687', r_ui=1.0, est=1.2136274859308211, details={'was_impossible': False}),
#  Prediction(uid='380', iid='121', r_ui=3.0, est=3.033101837487516, details={'was_impossible': False}),
#  Prediction(uid='537', iid='11', r_ui=3.0, est=2.903642534354556, details={'was_impossible': False}),
#  Prediction(uid='500', iid='755', r_ui=3.0, est=2.996225425027865, details={'was_impossible': False}),
#  Prediction(uid='579', iid='1446', r_ui=2.0, est=3.096234922485775, details={'was_impossible': False}),
#  Prediction(uid='173', iid='259', r_ui=3.0, est=3.3237823346020017, details={'was_impossible': False}),
#  Prediction(uid='798', iid='402', r_ui=3.0, est=3.244551775691611, details={'was_impossible': False}),
#  Prediction(uid='429', iid='847', r_ui=3.0, est=3.772403324639469, details={'was_impossible': False}),
#  Prediction(uid='276', iid='930', r_ui=2.0, est=2.8024746402151313, details={'was_impossible': False}),
#  Prediction(uid='655', iid='722', r_ui=1.0, est=2.2527938527785354, details={'was_impossible': False}),
#  Prediction(uid='236', iid='506', r_ui=5.0, est=3.6204169985928116, details={'was_impossible': False}),
#  Prediction(uid='130', iid='452', r_ui=4.0, est=3.9830038544189534, details={'was_impossible': False}),
#  Prediction(uid='891', iid='323', r_ui=3.0, est=3.460202907683537, details={'was_impossible': False}),
#  Prediction(uid='707', iid='283', r_ui=4.0, est=3.7839413481031174, details={'was_impossible': False}),
#  Prediction(uid='239', iid='954', r_ui=5.0, est=3.4710848560958985, details={'was_impossible': False}),
#  Prediction(uid='374', iid='829', r_ui=2.0, est=2.899626254580167, details={'was_impossible': False}),
#  Prediction(uid='805', iid='866', r_ui=1.0, est=3.1436625116015877, details={'was_impossible': False}),
#  Prediction(uid='932', iid='38', r_ui=2.0, est=2.973852370890619, details={'was_impossible': False}),
#  Prediction(uid='249', iid='789', r_ui=5.0, est=4.182687107406932, details={'was_impossible': False}),
#  Prediction(uid='90', iid='750', r_ui=4.0, est=4.489961001937193, details={'was_impossible': False}),
#  Prediction(uid='60', iid='209', r_ui=5.0, est=4.05935951011536, details={'was_impossible': False}),
#  Prediction(uid='927', iid='255', r_ui=4.0, est=3.6168918732995534, details={'was_impossible': False}),
#  Prediction(uid='669', iid='121', r_ui=3.0, est=3.0950276449133365, details={'was_impossible': False}),
#  Prediction(uid='339', iid='380', r_ui=3.0, est=3.691564486259327, details={'was_impossible': False}),
#  Prediction(uid='372', iid='561', r_ui=5.0, est=3.988565743192048, details={'was_impossible': False}),
#  Prediction(uid='664', iid='654', r_ui=5.0, est=4.195993293431415, details={'was_impossible': False}),
#  Prediction(uid='7', iid='101', r_ui=5.0, est=4.173153105629581, details={'was_impossible': False}),
#  Prediction(uid='708', iid='319', r_ui=5.0, est=2.8572375396842586, details={'was_impossible': False}),
#  Prediction(uid='867', iid='289', r_ui=5.0, est=3.178389112118802, details={'was_impossible': False}),
#  Prediction(uid='339', iid='573', r_ui=3.0, est=3.2780329115755826, details={'was_impossible': False}),
#  Prediction(uid='523', iid='153', r_ui=4.0, est=4.224600227713863, details={'was_impossible': False}),
#  Prediction(uid='881', iid='399', r_ui=4.0, est=3.1911033986807404, details={'was_impossible': False}),
#  Prediction(uid='201', iid='705', r_ui=3.0, est=3.7331144799395584, details={'was_impossible': False}),
#  Prediction(uid='334', iid='204', r_ui=4.0, est=3.6913953630577048, details={'was_impossible': False}),
#  Prediction(uid='653', iid='425', r_ui=2.0, est=3.16507844451255, details={'was_impossible': False}),
#  Prediction(uid='47', iid='995', r_ui=3.0, est=3.758962757795513, details={'was_impossible': False}),
#  Prediction(uid='532', iid='227', r_ui=4.0, est=3.6860816131059613, details={'was_impossible': False}),
#  Prediction(uid='815', iid='1204', r_ui=5.0, est=3.418312969635573, details={'was_impossible': False}),
#  Prediction(uid='207', iid='156', r_ui=2.0, est=3.1906442846581675, details={'was_impossible': False}),
#  Prediction(uid='828', iid='1062', r_ui=4.0, est=3.269887119129498, details={'was_impossible': False}),
#  Prediction(uid='848', iid='42', r_ui=2.0, est=4.266559028378023, details={'was_impossible': False}),
#  Prediction(uid='363', iid='1099', r_ui=2.0, est=3.288118774331665, details={'was_impossible': False}),
#  Prediction(uid='790', iid='790', r_ui=2.0, est=2.661694235295519, details={'was_impossible': False}),
#  Prediction(uid='15', iid='127', r_ui=2.0, est=3.986034965932987, details={'was_impossible': False}),
#  Prediction(uid='903', iid='56', r_ui=5.0, est=4.7485690154543345, details={'was_impossible': False}),
#  Prediction(uid='134', iid='301', r_ui=2.0, est=3.4245265452725016, details={'was_impossible': False}),
#  Prediction(uid='896', iid='525', r_ui=5.0, est=3.3399672853045153, details={'was_impossible': False}),
#  Prediction(uid='539', iid='19', r_ui=5.0, est=4.419215738096244, details={'was_impossible': False}),
#  Prediction(uid='838', iid='584', r_ui=4.0, est=3.9486678870657923, details={'was_impossible': False}),
#  Prediction(uid='929', iid='204', r_ui=4.0, est=3.555377371269574, details={'was_impossible': False}),
#  Prediction(uid='659', iid='524', r_ui=4.0, est=3.8422162777258912, details={'was_impossible': False}),
#  Prediction(uid='821', iid='495', r_ui=5.0, est=4.169015066209187, details={'was_impossible': False}),
#  Prediction(uid='511', iid='340', r_ui=4.0, est=4.0494620031473545, details={'was_impossible': False}),
#  Prediction(uid='191', iid='331', r_ui=4.0, est=3.6636521944302824, details={'was_impossible': False}),
#  Prediction(uid='807', iid='477', r_ui=4.0, est=3.3380522756444053, details={'was_impossible': False}),
#  Prediction(uid='181', iid='690', r_ui=3.0, est=2.1078034029860557, details={'was_impossible': False}),
#  Prediction(uid='293', iid='467', r_ui=4.0, est=3.211406820713958, details={'was_impossible': False}),
#  Prediction(uid='416', iid='895', r_ui=4.0, est=3.6316970415186347, details={'was_impossible': False}),
#  Prediction(uid='650', iid='597', r_ui=3.0, est=2.708736497799075, details={'was_impossible': False}),
#  Prediction(uid='538', iid='294', r_ui=3.0, est=2.6421979394805533, details={'was_impossible': False}),
#  Prediction(uid='699', iid='294', r_ui=3.0, est=3.423537666753058, details={'was_impossible': False}),
#  Prediction(uid='77', iid='176', r_ui=4.0, est=3.7660346283343493, details={'was_impossible': False}),
#  Prediction(uid='598', iid='751', r_ui=3.0, est=3.4616684938730704, details={'was_impossible': False}),
#  Prediction(uid='315', iid='121', r_ui=2.0, est=3.4147491741814013, details={'was_impossible': False}),
#  Prediction(uid='380', iid='183', r_ui=4.0, est=3.678943306049492, details={'was_impossible': False}),
#  Prediction(uid='825', iid='148', r_ui=4.0, est=3.8275181185497145, details={'was_impossible': False}),
#  Prediction(uid='345', iid='1281', r_ui=4.0, est=3.281151222761209, details={'was_impossible': False}),
#  Prediction(uid='389', iid='1119', r_ui=3.0, est=3.304610742946994, details={'was_impossible': False}),
#  Prediction(uid='554', iid='229', r_ui=3.0, est=3.313814334603481, details={'was_impossible': False}),
#  Prediction(uid='207', iid='540', r_ui=3.0, est=2.1405952437780575, details={'was_impossible': False}),
#  Prediction(uid='883', iid='147', r_ui=2.0, est=3.7318479292584965, details={'was_impossible': False}),
#  Prediction(uid='747', iid='835', r_ui=3.0, est=4.156485621035948, details={'was_impossible': False}),
#  Prediction(uid='864', iid='625', r_ui=4.0, est=3.617285272628139, details={'was_impossible': False}),
#  Prediction(uid='664', iid='70', r_ui=3.0, est=3.522372650273024, details={'was_impossible': False}),
#  Prediction(uid='488', iid='198', r_ui=4.0, est=3.34191784532851, details={'was_impossible': False}),
#  Prediction(uid='95', iid='385', r_ui=4.0, est=3.7199968151789355, details={'was_impossible': False}),
#  Prediction(uid='655', iid='396', r_ui=2.0, est=2.234368543844522, details={'was_impossible': False}),
#  Prediction(uid='451', iid='879', r_ui=4.0, est=2.478585548148946, details={'was_impossible': False}),
#  Prediction(uid='887', iid='91', r_ui=5.0, est=4.106459527018334, details={'was_impossible': False}),
#  Prediction(uid='529', iid='309', r_ui=3.0, est=3.5748832080412747, details={'was_impossible': False}),
#  Prediction(uid='682', iid='56', r_ui=4.0, est=3.2634624876313874, details={'was_impossible': False}),
#  Prediction(uid='113', iid='303', r_ui=5.0, est=4.095253434810627, details={'was_impossible': False}),
#  Prediction(uid='572', iid='284', r_ui=3.0, est=3.0526865535123346, details={'was_impossible': False}),
#  Prediction(uid='655', iid='594', r_ui=3.0, est=2.518524259707152, details={'was_impossible': False}),
#  Prediction(uid='10', iid='527', r_ui=4.0, est=4.607042435814979, details={'was_impossible': False}),
#  Prediction(uid='640', iid='750', r_ui=5.0, est=4.483620213823665, details={'was_impossible': False}),
#  Prediction(uid='291', iid='672', r_ui=3.0, est=3.3082023446883526, details={'was_impossible': False}),
#  Prediction(uid='503', iid='402', r_ui=3.0, est=3.9308281720023266, details={'was_impossible': False}),
#  Prediction(uid='276', iid='432', r_ui=5.0, est=3.4715857529842977, details={'was_impossible': False}),
#  Prediction(uid='102', iid='720', r_ui=2.0, est=2.322703568855312, details={'was_impossible': False}),
#  Prediction(uid='497', iid='588', r_ui=4.0, est=3.4172376776813045, details={'was_impossible': False}),
#  Prediction(uid='207', iid='233', r_ui=3.0, est=2.8765485049496675, details={'was_impossible': False}),
#  Prediction(uid='417', iid='3', r_ui=4.0, est=2.6176597970976068, details={'was_impossible': False}),
#  Prediction(uid='506', iid='239', r_ui=3.0, est=3.861748503770918, details={'was_impossible': False}),
#  Prediction(uid='6', iid='127', r_ui=5.0, est=4.336677929244034, details={'was_impossible': False}),
#  Prediction(uid='345', iid='1221', r_ui=3.0, est=3.533835350538371, details={'was_impossible': False}),
#  Prediction(uid='267', iid='239', r_ui=4.0, est=3.773056298535946, details={'was_impossible': False}),
#  Prediction(uid='222', iid='446', r_ui=3.0, est=2.808522503308887, details={'was_impossible': False}),
#  Prediction(uid='815', iid='252', r_ui=2.0, est=3.2176004851970097, details={'was_impossible': False}),
#  Prediction(uid='533', iid='742', r_ui=4.0, est=3.0821077516377033, details={'was_impossible': False}),
#  Prediction(uid='897', iid='186', r_ui=5.0, est=3.7411452776261918, details={'was_impossible': False}),
#  Prediction(uid='889', iid='182', r_ui=4.0, est=3.500294309477723, details={'was_impossible': False}),
#  Prediction(uid='193', iid='301', r_ui=4.0, est=2.8000027929662403, details={'was_impossible': False}),
#  Prediction(uid='42', iid='282', r_ui=4.0, est=4.008042582622601, details={'was_impossible': False}),
#  Prediction(uid='290', iid='181', r_ui=5.0, est=4.461527164293453, details={'was_impossible': False}),
#  Prediction(uid='276', iid='392', r_ui=3.0, est=3.456690619895487, details={'was_impossible': False}),
#  Prediction(uid='342', iid='248', r_ui=3.0, est=3.613275376928382, details={'was_impossible': False}),
#  Prediction(uid='453', iid='298', r_ui=4.0, est=3.3843143747661846, details={'was_impossible': False}),
#  Prediction(uid='887', iid='710', r_ui=5.0, est=4.27651929028081, details={'was_impossible': False}),
#  Prediction(uid='405', iid='142', r_ui=1.0, est=2.494841898897268, details={'was_impossible': False}),
#  Prediction(uid='506', iid='655', r_ui=4.0, est=4.1748213364637765, details={'was_impossible': False}),
#  Prediction(uid='198', iid='684', r_ui=3.0, est=3.5464457346369325, details={'was_impossible': False}),
#  Prediction(uid='10', iid='155', r_ui=4.0, est=3.620701598161405, details={'was_impossible': False}),
#  Prediction(uid='8', iid='188', r_ui=5.0, est=3.5850702887290504, details={'was_impossible': False}),
#  Prediction(uid='903', iid='48', r_ui=4.0, est=4.612763633143514, details={'was_impossible': False}),
#  Prediction(uid='224', iid='731', r_ui=4.0, est=2.7613229624981233, details={'was_impossible': False}),
#  Prediction(uid='537', iid='642', r_ui=4.0, est=2.7103774674629655, details={'was_impossible': False}),
#  Prediction(uid='328', iid='70', r_ui=4.0, est=3.8884147813679717, details={'was_impossible': False}),
#  Prediction(uid='406', iid='1267', r_ui=3.0, est=2.9460676273531883, details={'was_impossible': False}),
#  Prediction(uid='303', iid='293', r_ui=4.0, est=4.1868118956902824, details={'was_impossible': False}),
#  Prediction(uid='187', iid='792', r_ui=5.0, est=3.6337056032681705, details={'was_impossible': False}),
#  Prediction(uid='560', iid='654', r_ui=5.0, est=4.07209433839232, details={'was_impossible': False}),
#  Prediction(uid='450', iid='477', r_ui=4.0, est=3.279939072541869, details={'was_impossible': False}),
#  Prediction(uid='174', iid='268', r_ui=5.0, est=4.267250724370097, details={'was_impossible': False}),
#  Prediction(uid='145', iid='692', r_ui=2.0, est=3.284449084004687, details={'was_impossible': False}),
#  Prediction(uid='710', iid='92', r_ui=3.0, est=3.5485975531374963, details={'was_impossible': False}),
#  Prediction(uid='846', iid='183', r_ui=4.0, est=4.3301015857961485, details={'was_impossible': False}),
#  Prediction(uid='293', iid='27', r_ui=3.0, est=2.5539658614891207, details={'was_impossible': False}),
#  Prediction(uid='615', iid='283', r_ui=4.0, est=4.075978994830037, details={'was_impossible': False}),
#  Prediction(uid='582', iid='300', r_ui=3.0, est=3.358930579242117, details={'was_impossible': False}),
#  Prediction(uid='435', iid='171', r_ui=5.0, est=3.8920663275286906, details={'was_impossible': False}),
#  Prediction(uid='261', iid='117', r_ui=4.0, est=4.6192982888384035, details={'was_impossible': False}),
#  Prediction(uid='516', iid='181', r_ui=4.0, est=4.202120085095851, details={'was_impossible': False}),
#  Prediction(uid='766', iid='198', r_ui=4.0, est=3.709119277695715, details={'was_impossible': False}),
#  Prediction(uid='659', iid='134', r_ui=4.0, est=4.294109087742372, details={'was_impossible': False}),
#  Prediction(uid='532', iid='1226', r_ui=4.0, est=4.0558988971897305, details={'was_impossible': False}),
#  Prediction(uid='152', iid='692', r_ui=5.0, est=4.355478791721358, details={'was_impossible': False}),
#  Prediction(uid='615', iid='269', r_ui=4.0, est=4.036868176012124, details={'was_impossible': False}),
#  Prediction(uid='224', iid='1381', r_ui=3.0, est=3.004812684175369, details={'was_impossible': False}),
#  Prediction(uid='414', iid='100', r_ui=5.0, est=4.536606488262484, details={'was_impossible': False}),
#  Prediction(uid='197', iid='190', r_ui=3.0, est=4.427796560199074, details={'was_impossible': False}),
#  Prediction(uid='313', iid='663', r_ui=5.0, est=3.9815211009295526, details={'was_impossible': False}),
#  Prediction(uid='134', iid='539', r_ui=4.0, est=2.827965951289439, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1405', r_ui=2.0, est=3.091788492425609, details={'was_impossible': False}),
#  Prediction(uid='778', iid='94', r_ui=2.0, est=2.2295560637924985, details={'was_impossible': False}),
#  Prediction(uid='497', iid='1210', r_ui=4.0, est=2.6232286209772737, details={'was_impossible': False}),
#  Prediction(uid='452', iid='510', r_ui=4.0, est=3.3148216052276243, details={'was_impossible': False}),
#  Prediction(uid='296', iid='248', r_ui=5.0, est=4.12216091644835, details={'was_impossible': False}),
#  Prediction(uid='43', iid='114', r_ui=5.0, est=4.561904247093198, details={'was_impossible': False}),
#  Prediction(uid='158', iid='809', r_ui=3.0, est=3.3817318891843744, details={'was_impossible': False}),
#  Prediction(uid='405', iid='67', r_ui=5.0, est=1.5604768906432451, details={'was_impossible': False}),
#  Prediction(uid='119', iid='526', r_ui=2.0, est=4.056588104015777, details={'was_impossible': False}),
#  Prediction(uid='189', iid='525', r_ui=5.0, est=4.424554879933223, details={'was_impossible': False}),
#  Prediction(uid='618', iid='28', r_ui=4.0, est=3.645493557191534, details={'was_impossible': False}),
#  Prediction(uid='349', iid='126', r_ui=2.0, est=3.7526835500462155, details={'was_impossible': False}),
#  Prediction(uid='243', iid='221', r_ui=5.0, est=3.6408147140087004, details={'was_impossible': False}),
#  Prediction(uid='902', iid='306', r_ui=4.0, est=3.832715204333717, details={'was_impossible': False}),
#  Prediction(uid='399', iid='84', r_ui=2.0, est=2.7894075823664934, details={'was_impossible': False}),
#  Prediction(uid='332', iid='50', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='643', iid='956', r_ui=4.0, est=3.9650120335335544, details={'was_impossible': False}),
#  Prediction(uid='161', iid='197', r_ui=3.0, est=2.960768096975748, details={'was_impossible': False}),
#  Prediction(uid='293', iid='200', r_ui=4.0, est=3.490566033745788, details={'was_impossible': False}),
#  Prediction(uid='852', iid='100', r_ui=4.0, est=4.299232996016782, details={'was_impossible': False}),
#  Prediction(uid='878', iid='732', r_ui=4.0, est=3.0086418988570944, details={'was_impossible': False}),
#  Prediction(uid='749', iid='23', r_ui=3.0, est=3.886933194074091, details={'was_impossible': False}),
#  Prediction(uid='846', iid='738', r_ui=4.0, est=3.0150386796068886, details={'was_impossible': False}),
#  Prediction(uid='151', iid='627', r_ui=2.0, est=3.1814916096447607, details={'was_impossible': False}),
#  Prediction(uid='450', iid='131', r_ui=4.0, est=3.9815145877113856, details={'was_impossible': False}),
#  Prediction(uid='887', iid='477', r_ui=1.0, est=3.8975777964176492, details={'was_impossible': False}),
#  Prediction(uid='14', iid='382', r_ui=5.0, est=3.8859319556225893, details={'was_impossible': False}),
#  Prediction(uid='606', iid='620', r_ui=4.0, est=3.636715042483496, details={'was_impossible': False}),
#  Prediction(uid='327', iid='275', r_ui=4.0, est=3.904052216927157, details={'was_impossible': False}),
#  Prediction(uid='472', iid='49', r_ui=5.0, est=4.254601596788074, details={'was_impossible': False}),
#  Prediction(uid='174', iid='269', r_ui=5.0, est=4.4733266971376295, details={'was_impossible': False}),
#  Prediction(uid='543', iid='237', r_ui=4.0, est=3.4313591225883986, details={'was_impossible': False}),
#  Prediction(uid='201', iid='406', r_ui=1.0, est=1.7922495084593364, details={'was_impossible': False}),
#  Prediction(uid='385', iid='919', r_ui=4.0, est=3.4679314046318517, details={'was_impossible': False}),
#  Prediction(uid='64', iid='161', r_ui=3.0, est=3.3905758495083416, details={'was_impossible': False}),
#  Prediction(uid='151', iid='638', r_ui=5.0, est=3.9777554473412806, details={'was_impossible': False}),
#  Prediction(uid='38', iid='122', r_ui=1.0, est=3.2142871868417506, details={'was_impossible': False}),
#  Prediction(uid='227', iid='244', r_ui=3.0, est=3.3607857479427343, details={'was_impossible': False}),
#  Prediction(uid='417', iid='248', r_ui=4.0, est=3.6326050692937786, details={'was_impossible': False}),
#  Prediction(uid='210', iid='404', r_ui=5.0, est=4.057309495027152, details={'was_impossible': False}),
#  Prediction(uid='465', iid='109', r_ui=3.0, est=3.026214754282983, details={'was_impossible': False}),
#  Prediction(uid='130', iid='1215', r_ui=2.0, est=3.057472415930097, details={'was_impossible': False}),
#  Prediction(uid='454', iid='22', r_ui=4.0, est=3.8339079822832254, details={'was_impossible': False}),
#  Prediction(uid='619', iid='187', r_ui=5.0, est=3.9220387751483283, details={'was_impossible': False}),
#  Prediction(uid='921', iid='313', r_ui=5.0, est=4.381348895779031, details={'was_impossible': False}),
#  Prediction(uid='72', iid='628', r_ui=4.0, est=3.479882183898986, details={'was_impossible': False}),
#  Prediction(uid='659', iid='448', r_ui=4.0, est=3.562237694507495, details={'was_impossible': False}),
#  Prediction(uid='732', iid='321', r_ui=3.0, est=3.5400120760862803, details={'was_impossible': False}),
#  Prediction(uid='452', iid='475', r_ui=2.0, est=3.069374441000198, details={'was_impossible': False}),
#  Prediction(uid='268', iid='248', r_ui=3.0, est=3.5809779939810222, details={'was_impossible': False}),
#  Prediction(uid='819', iid='268', r_ui=4.0, est=3.6374830384888113, details={'was_impossible': False}),
#  Prediction(uid='566', iid='163', r_ui=5.0, est=3.62322410175507, details={'was_impossible': False}),
#  Prediction(uid='124', iid='79', r_ui=3.0, est=3.4090207382080915, details={'was_impossible': False}),
#  Prediction(uid='923', iid='333', r_ui=5.0, est=4.281998132822417, details={'was_impossible': False}),
#  Prediction(uid='481', iid='663', r_ui=4.0, est=3.975009311978072, details={'was_impossible': False}),
#  Prediction(uid='312', iid='208', r_ui=5.0, est=4.268736049448229, details={'was_impossible': False}),
#  Prediction(uid='151', iid='1', r_ui=5.0, est=4.126272216633448, details={'was_impossible': False}),
#  Prediction(uid='744', iid='127', r_ui=5.0, est=4.180662479387715, details={'was_impossible': False}),
#  Prediction(uid='308', iid='129', r_ui=5.0, est=4.129628505255037, details={'was_impossible': False}),
#  Prediction(uid='474', iid='288', r_ui=3.0, est=4.060403587181839, details={'was_impossible': False}),
#  Prediction(uid='601', iid='1039', r_ui=4.0, est=3.9381446808786706, details={'was_impossible': False}),
#  Prediction(uid='82', iid='475', r_ui=1.0, est=3.403519569546402, details={'was_impossible': False}),
#  Prediction(uid='286', iid='290', r_ui=3.0, est=3.4670747446717374, details={'was_impossible': False}),
#  Prediction(uid='655', iid='781', r_ui=1.0, est=2.5468039801429545, details={'was_impossible': False}),
#  Prediction(uid='225', iid='194', r_ui=5.0, est=4.9055055691911535, details={'was_impossible': False}),
#  Prediction(uid='922', iid='699', r_ui=3.0, est=3.7873885981188797, details={'was_impossible': False}),
#  Prediction(uid='943', iid='393', r_ui=2.0, est=3.60712136683037, details={'was_impossible': False}),
#  Prediction(uid='417', iid='628', r_ui=3.0, est=3.3424881575299024, details={'was_impossible': False}),
#  Prediction(uid='591', iid='1017', r_ui=3.0, est=3.077330386135604, details={'was_impossible': False}),
#  Prediction(uid='94', iid='223', r_ui=5.0, est=4.490391044234126, details={'was_impossible': False}),
#  Prediction(uid='445', iid='831', r_ui=1.0, est=1.2282406636939456, details={'was_impossible': False}),
#  Prediction(uid='54', iid='24', r_ui=1.0, est=3.98753717059176, details={'was_impossible': False}),
#  Prediction(uid='327', iid='42', r_ui=3.0, est=3.8107345783587716, details={'was_impossible': False}),
#  Prediction(uid='474', iid='357', r_ui=5.0, est=4.8028786888278026, details={'was_impossible': False}),
#  Prediction(uid='493', iid='298', r_ui=3.0, est=3.6263194917126222, details={'was_impossible': False}),
#  Prediction(uid='406', iid='174', r_ui=4.0, est=4.312860621522146, details={'was_impossible': False}),
#  Prediction(uid='18', iid='631', r_ui=5.0, est=3.9076414039555183, details={'was_impossible': False}),
#  Prediction(uid='442', iid='986', r_ui=1.0, est=2.8002114264942524, details={'was_impossible': False}),
#  Prediction(uid='321', iid='498', r_ui=5.0, est=3.7062184665243683, details={'was_impossible': False}),
#  Prediction(uid='698', iid='435', r_ui=3.0, est=3.123975215372492, details={'was_impossible': False}),
#  Prediction(uid='401', iid='65', r_ui=4.0, est=3.191799340249144, details={'was_impossible': False}),
#  Prediction(uid='291', iid='790', r_ui=4.0, est=3.41749122390486, details={'was_impossible': False}),
#  Prediction(uid='871', iid='1345', r_ui=3.0, est=3.069723029380395, details={'was_impossible': False}),
#  Prediction(uid='303', iid='426', r_ui=3.0, est=2.8045932821860675, details={'was_impossible': False}),
#  Prediction(uid='573', iid='519', r_ui=4.0, est=3.853163236289482, details={'was_impossible': False}),
#  Prediction(uid='551', iid='505', r_ui=5.0, est=4.051405590888539, details={'was_impossible': False}),
#  Prediction(uid='327', iid='718', r_ui=4.0, est=2.9338916293603763, details={'was_impossible': False}),
#  Prediction(uid='885', iid='1030', r_ui=1.0, est=2.3235170500495177, details={'was_impossible': False}),
#  Prediction(uid='694', iid='449', r_ui=4.0, est=3.279202623161029, details={'was_impossible': False}),
#  Prediction(uid='790', iid='577', r_ui=2.0, est=1.9745365968784314, details={'was_impossible': False}),
#  Prediction(uid='283', iid='95', r_ui=5.0, est=4.355958097114614, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1240', r_ui=1.0, est=3.502135568166054, details={'was_impossible': False}),
#  Prediction(uid='873', iid='258', r_ui=3.0, est=3.5711673580251206, details={'was_impossible': False}),
#  Prediction(uid='95', iid='143', r_ui=4.0, est=4.103050755528671, details={'was_impossible': False}),
#  Prediction(uid='619', iid='55', r_ui=1.0, est=3.8171317548538446, details={'was_impossible': False}),
#  Prediction(uid='892', iid='69', r_ui=5.0, est=4.459175108495361, details={'was_impossible': False}),
#  Prediction(uid='332', iid='332', r_ui=4.0, est=4.602289665330718, details={'was_impossible': False}),
#  Prediction(uid='556', iid='170', r_ui=4.0, est=4.827772684958542, details={'was_impossible': False}),
#  Prediction(uid='383', iid='180', r_ui=5.0, est=4.689546207493321, details={'was_impossible': False}),
#  Prediction(uid='587', iid='323', r_ui=4.0, est=2.7155861208514374, details={'was_impossible': False}),
#  Prediction(uid='802', iid='200', r_ui=4.0, est=3.7622568892912067, details={'was_impossible': False}),
#  Prediction(uid='514', iid='13', r_ui=3.0, est=3.421062733294669, details={'was_impossible': False}),
#  Prediction(uid='835', iid='257', r_ui=3.0, est=3.994118838913076, details={'was_impossible': False}),
#  Prediction(uid='870', iid='276', r_ui=4.0, est=3.829385050464234, details={'was_impossible': False}),
#  Prediction(uid='690', iid='63', r_ui=3.0, est=3.0801589706264414, details={'was_impossible': False}),
#  Prediction(uid='504', iid='257', r_ui=5.0, est=3.973002380206052, details={'was_impossible': False}),
#  Prediction(uid='33', iid='880', r_ui=3.0, est=3.5609758630535424, details={'was_impossible': False}),
#  Prediction(uid='592', iid='238', r_ui=5.0, est=4.3877867833532385, details={'was_impossible': False}),
#  Prediction(uid='246', iid='470', r_ui=4.0, est=3.0808203741510063, details={'was_impossible': False}),
#  Prediction(uid='661', iid='514', r_ui=3.0, est=4.018675863007015, details={'was_impossible': False}),
#  Prediction(uid='425', iid='252', r_ui=2.0, est=2.383736900419433, details={'was_impossible': False}),
#  Prediction(uid='536', iid='380', r_ui=4.0, est=3.781943056110707, details={'was_impossible': False}),
#  Prediction(uid='144', iid='1016', r_ui=3.0, est=3.676643369907829, details={'was_impossible': False}),
#  Prediction(uid='608', iid='58', r_ui=2.0, est=3.5970319659838013, details={'was_impossible': False}),
#  Prediction(uid='45', iid='225', r_ui=4.0, est=3.1563890471840828, details={'was_impossible': False}),
#  Prediction(uid='92', iid='566', r_ui=4.0, est=3.4216220449669885, details={'was_impossible': False}),
#  Prediction(uid='331', iid='178', r_ui=3.0, est=4.126914792243234, details={'was_impossible': False}),
#  Prediction(uid='401', iid='501', r_ui=2.0, est=2.349774752420989, details={'was_impossible': False}),
#  Prediction(uid='358', iid='179', r_ui=4.0, est=4.4141252388049, details={'was_impossible': False}),
#  Prediction(uid='862', iid='982', r_ui=4.0, est=3.6930057254922835, details={'was_impossible': False}),
#  Prediction(uid='299', iid='724', r_ui=3.0, est=3.492414119932452, details={'was_impossible': False}),
#  Prediction(uid='291', iid='420', r_ui=4.0, est=3.87948683009776, details={'was_impossible': False}),
#  Prediction(uid='790', iid='29', r_ui=2.0, est=2.719870108633871, details={'was_impossible': False}),
#  Prediction(uid='554', iid='69', r_ui=5.0, est=4.207035989892731, details={'was_impossible': False}),
#  Prediction(uid='110', iid='385', r_ui=3.0, est=3.191830665526921, details={'was_impossible': False}),
#  Prediction(uid='44', iid='450', r_ui=2.0, est=2.2118889812243605, details={'was_impossible': False}),
#  Prediction(uid='325', iid='200', r_ui=2.0, est=3.607991126808126, details={'was_impossible': False}),
#  Prediction(uid='804', iid='97', r_ui=4.0, est=4.057021737988064, details={'was_impossible': False}),
#  Prediction(uid='299', iid='730', r_ui=4.0, est=3.198796911067484, details={'was_impossible': False}),
#  Prediction(uid='382', iid='100', r_ui=4.0, est=3.9230536509311063, details={'was_impossible': False}),
#  Prediction(uid='536', iid='73', r_ui=4.0, est=3.9144790695842624, details={'was_impossible': False}),
#  Prediction(uid='721', iid='527', r_ui=5.0, est=4.324390329533578, details={'was_impossible': False}),
#  Prediction(uid='18', iid='381', r_ui=4.0, est=3.95741800454582, details={'was_impossible': False}),
#  Prediction(uid='361', iid='611', r_ui=4.0, est=4.204217469062022, details={'was_impossible': False}),
#  Prediction(uid='189', iid='174', r_ui=5.0, est=4.742982844330995, details={'was_impossible': False}),
#  Prediction(uid='296', iid='514', r_ui=5.0, est=4.231271499312094, details={'was_impossible': False}),
#  Prediction(uid='354', iid='13', r_ui=3.0, est=3.2939176268122625, details={'was_impossible': False}),
#  Prediction(uid='627', iid='187', r_ui=5.0, est=3.851816936754946, details={'was_impossible': False}),
#  Prediction(uid='381', iid='682', r_ui=2.0, est=3.188410516139398, details={'was_impossible': False}),
#  Prediction(uid='865', iid='7', r_ui=5.0, est=2.8401055435843796, details={'was_impossible': False}),
#  Prediction(uid='130', iid='168', r_ui=3.0, est=4.341483020737308, details={'was_impossible': False}),
#  Prediction(uid='63', iid='137', r_ui=4.0, est=3.4992094093338757, details={'was_impossible': False}),
#  Prediction(uid='59', iid='1047', r_ui=2.0, est=3.100123158153791, details={'was_impossible': False}),
#  Prediction(uid='648', iid='1060', r_ui=2.0, est=3.2386921960877304, details={'was_impossible': False}),
#  Prediction(uid='716', iid='428', r_ui=3.0, est=4.061566741184913, details={'was_impossible': False}),
#  Prediction(uid='437', iid='812', r_ui=3.0, est=3.0442111733983768, details={'was_impossible': False}),
#  Prediction(uid='13', iid='912', r_ui=2.0, est=3.1622881675957886, details={'was_impossible': False}),
#  Prediction(uid='551', iid='1087', r_ui=1.0, est=3.6987168179389567, details={'was_impossible': False}),
#  Prediction(uid='336', iid='790', r_ui=2.0, est=2.553467293303964, details={'was_impossible': False}),
#  Prediction(uid='305', iid='960', r_ui=1.0, est=2.9576908750394044, details={'was_impossible': False}),
#  Prediction(uid='622', iid='725', r_ui=3.0, est=3.101522567668911, details={'was_impossible': False}),
#  Prediction(uid='543', iid='684', r_ui=4.0, est=3.575704842976199, details={'was_impossible': False}),
#  Prediction(uid='85', iid='1103', r_ui=3.0, est=3.746621989340802, details={'was_impossible': False}),
#  Prediction(uid='609', iid='313', r_ui=5.0, est=3.9351090817920813, details={'was_impossible': False}),
#  Prediction(uid='781', iid='324', r_ui=4.0, est=3.000146299697345, details={'was_impossible': False}),
#  Prediction(uid='479', iid='274', r_ui=4.0, est=3.478348989144481, details={'was_impossible': False}),
#  Prediction(uid='254', iid='498', r_ui=4.0, est=3.6405155374781795, details={'was_impossible': False}),
#  Prediction(uid='709', iid='379', r_ui=3.0, est=3.266112543689782, details={'was_impossible': False}),
#  Prediction(uid='540', iid='50', r_ui=5.0, est=4.570178135760242, details={'was_impossible': False}),
#  Prediction(uid='682', iid='95', r_ui=5.0, est=3.6186671785937725, details={'was_impossible': False}),
#  Prediction(uid='291', iid='1178', r_ui=4.0, est=2.682541750127259, details={'was_impossible': False}),
#  Prediction(uid='1', iid='148', r_ui=2.0, est=3.0177262586593683, details={'was_impossible': False}),
#  Prediction(uid='683', iid='289', r_ui=4.0, est=2.827413273246715, details={'was_impossible': False}),
#  Prediction(uid='543', iid='531', r_ui=4.0, est=3.7857751315537067, details={'was_impossible': False}),
#  Prediction(uid='795', iid='826', r_ui=3.0, est=2.474256013751054, details={'was_impossible': False}),
#  Prediction(uid='699', iid='683', r_ui=3.0, est=2.407422516273827, details={'was_impossible': False}),
#  Prediction(uid='627', iid='64', r_ui=5.0, est=4.121520318470079, details={'was_impossible': False}),
#  Prediction(uid='22', iid='172', r_ui=4.0, est=4.278107183364034, details={'was_impossible': False}),
#  Prediction(uid='450', iid='221', r_ui=4.0, est=4.126715407138935, details={'was_impossible': False}),
#  Prediction(uid='807', iid='418', r_ui=4.0, est=3.869678833406166, details={'was_impossible': False}),
#  Prediction(uid='842', iid='340', r_ui=5.0, est=3.5774609847742154, details={'was_impossible': False}),
#  Prediction(uid='274', iid='744', r_ui=5.0, est=4.2124691061754165, details={'was_impossible': False}),
#  Prediction(uid='262', iid='44', r_ui=2.0, est=3.2006402169387065, details={'was_impossible': False}),
#  Prediction(uid='1', iid='35', r_ui=1.0, est=3.0937874094086, details={'was_impossible': False}),
#  Prediction(uid='312', iid='525', r_ui=5.0, est=4.4248092335749085, details={'was_impossible': False}),
#  Prediction(uid='447', iid='248', r_ui=5.0, est=3.8367455011809017, details={'was_impossible': False}),
#  Prediction(uid='466', iid='127', r_ui=3.0, est=3.9417837772380433, details={'was_impossible': False}),
#  Prediction(uid='296', iid='22', r_ui=4.0, est=4.826260106586846, details={'was_impossible': False}),
#  Prediction(uid='624', iid='544', r_ui=4.0, est=3.3078078822972143, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1552', r_ui=2.0, est=3.2957438207373744, details={'was_impossible': False}),
#  Prediction(uid='425', iid='669', r_ui=3.0, est=1.8960067250812516, details={'was_impossible': False}),
#  Prediction(uid='932', iid='491', r_ui=5.0, est=4.0667391379142375, details={'was_impossible': False}),
#  Prediction(uid='246', iid='385', r_ui=1.0, est=2.771660851014193, details={'was_impossible': False}),
#  Prediction(uid='758', iid='364', r_ui=4.0, est=3.2112748874125865, details={'was_impossible': False}),
#  Prediction(uid='846', iid='675', r_ui=2.0, est=3.745951076802909, details={'was_impossible': False}),
#  Prediction(uid='379', iid='192', r_ui=4.0, est=4.771884098118223, details={'was_impossible': False}),
#  Prediction(uid='870', iid='479', r_ui=5.0, est=3.97619382515955, details={'was_impossible': False}),
#  Prediction(uid='778', iid='780', r_ui=3.0, est=2.1492445880977407, details={'was_impossible': False}),
#  Prediction(uid='474', iid='291', r_ui=4.0, est=3.5234454962413353, details={'was_impossible': False}),
#  Prediction(uid='497', iid='810', r_ui=3.0, est=2.766984144529903, details={'was_impossible': False}),
#  Prediction(uid='95', iid='102', r_ui=4.0, est=2.7927690376404226, details={'was_impossible': False}),
#  Prediction(uid='655', iid='775', r_ui=2.0, est=2.256884396061331, details={'was_impossible': False}),
#  Prediction(uid='198', iid='64', r_ui=4.0, est=4.284764748481267, details={'was_impossible': False}),
#  Prediction(uid='327', iid='1012', r_ui=2.0, est=3.2227757684405325, details={'was_impossible': False}),
#  Prediction(uid='881', iid='392', r_ui=5.0, est=3.2088670099092265, details={'was_impossible': False}),
#  Prediction(uid='417', iid='117', r_ui=4.0, est=3.139270672309516, details={'was_impossible': False}),
#  Prediction(uid='788', iid='300', r_ui=5.0, est=3.369182072410541, details={'was_impossible': False}),
#  Prediction(uid='43', iid='283', r_ui=2.0, est=3.9029353621241585, details={'was_impossible': False}),
#  Prediction(uid='57', iid='496', r_ui=4.0, est=4.256919761563452, details={'was_impossible': False}),
#  Prediction(uid='36', iid='333', r_ui=4.0, est=3.896964722871778, details={'was_impossible': False}),
#  Prediction(uid='682', iid='699', r_ui=3.0, est=3.7410639964247476, details={'was_impossible': False}),
#  Prediction(uid='892', iid='144', r_ui=5.0, est=4.3363991788608045, details={'was_impossible': False}),
#  Prediction(uid='169', iid='429', r_ui=3.0, est=4.155221744703194, details={'was_impossible': False}),
#  Prediction(uid='500', iid='514', r_ui=5.0, est=4.124758887625064, details={'was_impossible': False}),
#  Prediction(uid='59', iid='951', r_ui=3.0, est=2.918045746401163, details={'was_impossible': False}),
#  Prediction(uid='234', iid='165', r_ui=5.0, est=3.2920966792588144, details={'was_impossible': False}),
#  Prediction(uid='758', iid='527', r_ui=5.0, est=4.3786817825903475, details={'was_impossible': False}),
#  Prediction(uid='11', iid='229', r_ui=4.0, est=3.1053521150327064, details={'was_impossible': False}),
#  Prediction(uid='399', iid='96', r_ui=3.0, est=3.569528984627475, details={'was_impossible': False}),
#  Prediction(uid='211', iid='127', r_ui=4.0, est=4.267911566641592, details={'was_impossible': False}),
#  Prediction(uid='686', iid='451', r_ui=4.0, est=3.98742316418416, details={'was_impossible': False}),
#  Prediction(uid='766', iid='527', r_ui=5.0, est=3.660619306148253, details={'was_impossible': False}),
#  Prediction(uid='416', iid='447', r_ui=4.0, est=3.6368578603657884, details={'was_impossible': False}),
#  Prediction(uid='541', iid='222', r_ui=4.0, est=4.044043812151351, details={'was_impossible': False}),
#  Prediction(uid='655', iid='113', r_ui=3.0, est=3.0285816917909996, details={'was_impossible': False}),
#  Prediction(uid='63', iid='250', r_ui=5.0, est=3.365072574859849, details={'was_impossible': False}),
#  Prediction(uid='846', iid='615', r_ui=5.0, est=4.197044617914833, details={'was_impossible': False}),
#  Prediction(uid='380', iid='356', r_ui=2.0, est=2.8790453093634056, details={'was_impossible': False}),
#  Prediction(uid='407', iid='519', r_ui=4.0, est=4.033223117972424, details={'was_impossible': False}),
#  Prediction(uid='472', iid='227', r_ui=5.0, est=4.331631295177803, details={'was_impossible': False}),
#  Prediction(uid='924', iid='318', r_ui=5.0, est=4.265590475225776, details={'was_impossible': False}),
#  Prediction(uid='742', iid='546', r_ui=1.0, est=2.9018174588355743, details={'was_impossible': False}),
#  Prediction(uid='13', iid='807', r_ui=1.0, est=2.5180505667976085, details={'was_impossible': False}),
#  Prediction(uid='312', iid='190', r_ui=5.0, est=4.58749773722005, details={'was_impossible': False}),
#  Prediction(uid='796', iid='178', r_ui=3.0, est=4.092653774325792, details={'was_impossible': False}),
#  Prediction(uid='330', iid='739', r_ui=5.0, est=4.573194347582311, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1346', r_ui=1.0, est=1.9384621361447651, details={'was_impossible': False}),
#  Prediction(uid='763', iid='357', r_ui=4.0, est=4.378172025446476, details={'was_impossible': False}),
#  Prediction(uid='559', iid='204', r_ui=3.0, est=3.534672377083254, details={'was_impossible': False}),
#  Prediction(uid='249', iid='546', r_ui=3.0, est=3.26467243731866, details={'was_impossible': False}),
#  Prediction(uid='50', iid='325', r_ui=1.0, est=2.5231808347882283, details={'was_impossible': False}),
#  Prediction(uid='371', iid='183', r_ui=5.0, est=4.4027890425828025, details={'was_impossible': False}),
#  Prediction(uid='643', iid='521', r_ui=4.0, est=3.9198010825133998, details={'was_impossible': False}),
#  Prediction(uid='342', iid='410', r_ui=3.0, est=3.2587809032016253, details={'was_impossible': False}),
#  Prediction(uid='601', iid='1047', r_ui=1.0, est=2.2800542547218545, details={'was_impossible': False}),
#  Prediction(uid='178', iid='98', r_ui=5.0, est=4.173771952769987, details={'was_impossible': False}),
#  Prediction(uid='437', iid='319', r_ui=5.0, est=2.366621278661794, details={'was_impossible': False}),
#  Prediction(uid='269', iid='55', r_ui=4.0, est=4.0965536192792475, details={'was_impossible': False}),
#  Prediction(uid='747', iid='135', r_ui=5.0, est=4.664384662439158, details={'was_impossible': False}),
#  Prediction(uid='435', iid='185', r_ui=4.0, est=4.190234039781026, details={'was_impossible': False}),
#  Prediction(uid='702', iid='294', r_ui=1.0, est=2.4148507660068845, details={'was_impossible': False}),
#  Prediction(uid='416', iid='56', r_ui=5.0, est=4.548320962267177, details={'was_impossible': False}),
#  Prediction(uid='358', iid='511', r_ui=2.0, est=3.886824483591868, details={'was_impossible': False}),
#  Prediction(uid='503', iid='121', r_ui=3.0, est=3.967022393370388, details={'was_impossible': False}),
#  Prediction(uid='233', iid='614', r_ui=4.0, est=4.109191982501541, details={'was_impossible': False}),
#  Prediction(uid='187', iid='65', r_ui=5.0, est=3.810923982231554, details={'was_impossible': False}),
#  Prediction(uid='897', iid='185', r_ui=5.0, est=4.293180184543488, details={'was_impossible': False}),
#  Prediction(uid='393', iid='136', r_ui=5.0, est=3.7336800840042486, details={'was_impossible': False}),
#  Prediction(uid='586', iid='182', r_ui=3.0, est=3.4928037842788697, details={'was_impossible': False}),
#  Prediction(uid='190', iid='300', r_ui=4.0, est=3.422200128563938, details={'was_impossible': False}),
#  Prediction(uid='6', iid='9', r_ui=4.0, est=3.838049505877115, details={'was_impossible': False}),
#  Prediction(uid='887', iid='969', r_ui=5.0, est=3.8792098257373726, details={'was_impossible': False}),
#  Prediction(uid='648', iid='22', r_ui=4.0, est=4.7527026292428065, details={'was_impossible': False}),
#  Prediction(uid='244', iid='941', r_ui=4.0, est=3.327907037139882, details={'was_impossible': False}),
#  Prediction(uid='737', iid='175', r_ui=5.0, est=3.7712271976102203, details={'was_impossible': False}),
#  Prediction(uid='466', iid='210', r_ui=4.0, est=3.977579678497497, details={'was_impossible': False}),
#  Prediction(uid='653', iid='696', r_ui=1.0, est=2.3799593607921268, details={'was_impossible': False}),
#  Prediction(uid='141', iid='407', r_ui=2.0, est=2.8372574903212686, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1044', r_ui=4.0, est=3.175336837982476, details={'was_impossible': False}),
#  Prediction(uid='796', iid='487', r_ui=5.0, est=4.234758070480267, details={'was_impossible': False}),
#  Prediction(uid='422', iid='458', r_ui=3.0, est=3.0558616094712323, details={'was_impossible': False}),
#  Prediction(uid='301', iid='333', r_ui=4.0, est=3.1072346318189714, details={'was_impossible': False}),
#  Prediction(uid='361', iid='226', r_ui=3.0, est=3.3541261964279903, details={'was_impossible': False}),
#  Prediction(uid='541', iid='62', r_ui=4.0, est=3.1612618847722302, details={'was_impossible': False}),
#  Prediction(uid='776', iid='318', r_ui=4.0, est=4.610402354278885, details={'was_impossible': False}),
#  Prediction(uid='471', iid='946', r_ui=2.0, est=3.095157673841452, details={'was_impossible': False}),
#  Prediction(uid='45', iid='118', r_ui=4.0, est=3.465505650216996, details={'was_impossible': False}),
#  Prediction(uid='454', iid='147', r_ui=3.0, est=2.725978182228569, details={'was_impossible': False}),
#  Prediction(uid='886', iid='1324', r_ui=2.0, est=3.1778728023008966, details={'was_impossible': False}),
#  Prediction(uid='868', iid='73', r_ui=1.0, est=2.966140002025764, details={'was_impossible': False}),
#  Prediction(uid='181', iid='683', r_ui=1.0, est=1.0516114914254997, details={'was_impossible': False}),
#  Prediction(uid='330', iid='204', r_ui=5.0, est=4.732077120398333, details={'was_impossible': False}),
#  Prediction(uid='93', iid='412', r_ui=2.0, est=2.433055530733016, details={'was_impossible': False}),
#  Prediction(uid='499', iid='300', r_ui=4.0, est=3.465026995517504, details={'was_impossible': False}),
#  Prediction(uid='350', iid='210', r_ui=4.0, est=4.207832033444842, details={'was_impossible': False}),
# ...
#  Prediction(uid='343', iid='68', r_ui=1.0, est=4.034559414636283, details={'was_impossible': False}),
#  Prediction(uid='602', iid='259', r_ui=4.0, est=3.3210256531729616, details={'was_impossible': False}),
#  Prediction(uid='881', iid='183', r_ui=4.0, est=3.808885709299431, details={'was_impossible': False}),
#  Prediction(uid='489', iid='876', r_ui=2.0, est=3.388680737038136, details={'was_impossible': False}),
#  Prediction(uid='380', iid='573', r_ui=1.0, est=2.7682651075481552, details={'was_impossible': False}),
#  Prediction(uid='472', iid='375', r_ui=5.0, est=3.2837576993296507, details={'was_impossible': False}),
#  Prediction(uid='455', iid='20', r_ui=3.0, est=3.21690288981423, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1184', r_ui=1.0, est=1.0898740232483215, details={'was_impossible': False}),
#  Prediction(uid='682', iid='728', r_ui=3.0, est=2.8904366322721367, details={'was_impossible': False}),
#  Prediction(uid='630', iid='322', r_ui=3.0, est=3.536859251318675, details={'was_impossible': False}),
#  Prediction(uid='557', iid='165', r_ui=5.0, est=4.257450594940514, details={'was_impossible': False}),
#  Prediction(uid='256', iid='222', r_ui=4.0, est=4.444369948699551, details={'was_impossible': False}),
#  Prediction(uid='699', iid='321', r_ui=3.0, est=3.0485765612840003, details={'was_impossible': False}),
#  Prediction(uid='608', iid='961', r_ui=4.0, est=3.731322632782931, details={'was_impossible': False}),
#  Prediction(uid='407', iid='185', r_ui=5.0, est=3.9489935430824343, details={'was_impossible': False}),
#  Prediction(uid='65', iid='427', r_ui=5.0, est=4.405225137093593, details={'was_impossible': False}),
#  Prediction(uid='916', iid='684', r_ui=3.0, est=3.4732533593583543, details={'was_impossible': False}),
#  Prediction(uid='523', iid='949', r_ui=5.0, est=4.194770803503013, details={'was_impossible': False}),
#  Prediction(uid='287', iid='952', r_ui=4.0, est=3.491031591371545, details={'was_impossible': False}),
#  Prediction(uid='389', iid='820', r_ui=3.0, est=2.6903945447180138, details={'was_impossible': False}),
#  Prediction(uid='264', iid='173', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='1', iid='176', r_ui=5.0, est=4.011811447684235, details={'was_impossible': False}),
#  Prediction(uid='217', iid='685', r_ui=5.0, est=3.0217929464440765, details={'was_impossible': False}),
#  Prediction(uid='704', iid='480', r_ui=5.0, est=4.201204117264778, details={'was_impossible': False}),
#  Prediction(uid='445', iid='689', r_ui=1.0, est=1.3081308923203496, details={'was_impossible': False}),
#  Prediction(uid='311', iid='98', r_ui=5.0, est=4.382849183320061, details={'was_impossible': False}),
#  Prediction(uid='943', iid='403', r_ui=4.0, est=3.869427717154572, details={'was_impossible': False}),
#  Prediction(uid='311', iid='183', r_ui=5.0, est=3.9974305136922275, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1129', r_ui=1.0, est=1.9340646999677482, details={'was_impossible': False}),
#  Prediction(uid='429', iid='231', r_ui=2.0, est=2.527786449945299, details={'was_impossible': False}),
#  Prediction(uid='853', iid='879', r_ui=4.0, est=3.151487796237675, details={'was_impossible': False}),
#  Prediction(uid='262', iid='955', r_ui=2.0, est=3.5525343426644955, details={'was_impossible': False}),
#  Prediction(uid='130', iid='79', r_ui=5.0, est=4.974364457096505, details={'was_impossible': False}),
#  Prediction(uid='297', iid='198', r_ui=3.0, est=3.591252176943047, details={'was_impossible': False}),
#  Prediction(uid='816', iid='271', r_ui=4.0, est=3.9511207134956368, details={'was_impossible': False}),
#  Prediction(uid='807', iid='265', r_ui=5.0, est=4.379108267510984, details={'was_impossible': False}),
#  Prediction(uid='318', iid='210', r_ui=4.0, est=3.807616806255826, details={'was_impossible': False}),
#  Prediction(uid='437', iid='969', r_ui=4.0, est=3.7017931686366907, details={'was_impossible': False}),
#  Prediction(uid='263', iid='732', r_ui=5.0, est=3.7826238214568773, details={'was_impossible': False}),
#  Prediction(uid='24', iid='727', r_ui=3.0, est=4.193936569662697, details={'was_impossible': False}),
#  Prediction(uid='645', iid='92', r_ui=3.0, est=3.816687111311875, details={'was_impossible': False}),
#  Prediction(uid='638', iid='226', r_ui=5.0, est=3.3217939870776316, details={'was_impossible': False}),
#  Prediction(uid='401', iid='111', r_ui=4.0, est=2.977633815385936, details={'was_impossible': False}),
#  Prediction(uid='325', iid='647', r_ui=5.0, est=3.88050108690882, details={'was_impossible': False}),
#  Prediction(uid='679', iid='721', r_ui=3.0, est=3.7535380547013886, details={'was_impossible': False}),
#  Prediction(uid='917', iid='879', r_ui=2.0, est=3.4527563687169858, details={'was_impossible': False}),
#  Prediction(uid='376', iid='197', r_ui=4.0, est=4.114342916271331, details={'was_impossible': False}),
#  Prediction(uid='864', iid='225', r_ui=3.0, est=2.9794449611831655, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1306', r_ui=1.0, est=2.292581811623507, details={'was_impossible': False}),
#  Prediction(uid='216', iid='169', r_ui=3.0, est=4.593966424939537, details={'was_impossible': False}),
#  Prediction(uid='455', iid='455', r_ui=3.0, est=3.336927954426156, details={'was_impossible': False}),
#  Prediction(uid='669', iid='276', r_ui=2.0, est=3.883046498343578, details={'was_impossible': False}),
#  Prediction(uid='389', iid='674', r_ui=2.0, est=3.2497733151161605, details={'was_impossible': False}),
#  Prediction(uid='580', iid='25', r_ui=3.0, est=3.54966341991666, details={'was_impossible': False}),
#  Prediction(uid='288', iid='136', r_ui=5.0, est=4.164014293068121, details={'was_impossible': False}),
#  Prediction(uid='218', iid='642', r_ui=3.0, est=3.441114043582951, details={'was_impossible': False}),
#  Prediction(uid='768', iid='762', r_ui=1.0, est=3.285239751924599, details={'was_impossible': False}),
#  Prediction(uid='71', iid='134', r_ui=3.0, est=3.8719699518473454, details={'was_impossible': False}),
#  Prediction(uid='790', iid='403', r_ui=4.0, est=2.9273809864830858, details={'was_impossible': False}),
#  Prediction(uid='864', iid='169', r_ui=5.0, est=4.644166105609038, details={'was_impossible': False}),
#  Prediction(uid='224', iid='591', r_ui=3.0, est=2.980707828102727, details={'was_impossible': False}),
#  Prediction(uid='470', iid='248', r_ui=3.0, est=3.7917650225710875, details={'was_impossible': False}),
#  Prediction(uid='452', iid='924', r_ui=5.0, est=3.694514739318695, details={'was_impossible': False}),
#  Prediction(uid='406', iid='22', r_ui=3.0, est=4.17235262171474, details={'was_impossible': False}),
#  Prediction(uid='472', iid='288', r_ui=5.0, est=4.333251833153468, details={'was_impossible': False}),
#  Prediction(uid='878', iid='140', r_ui=2.0, est=2.3811784566892853, details={'was_impossible': False}),
#  Prediction(uid='474', iid='1063', r_ui=5.0, est=3.8861785810491427, details={'was_impossible': False}),
#  Prediction(uid='757', iid='576', r_ui=3.0, est=2.9286793650737453, details={'was_impossible': False}),
#  Prediction(uid='331', iid='305', r_ui=5.0, est=3.5873929741428525, details={'was_impossible': False}),
#  Prediction(uid='7', iid='488', r_ui=4.0, est=4.388789819878879, details={'was_impossible': False}),
#  Prediction(uid='407', iid='388', r_ui=2.0, est=2.895618344398007, details={'was_impossible': False}),
#  Prediction(uid='339', iid='9', r_ui=5.0, est=4.369097731066468, details={'was_impossible': False}),
#  Prediction(uid='470', iid='288', r_ui=4.0, est=3.1143129467075554, details={'was_impossible': False}),
#  Prediction(uid='572', iid='289', r_ui=3.0, est=2.7361770821984273, details={'was_impossible': False}),
#  Prediction(uid='803', iid='306', r_ui=4.0, est=4.240170423192044, details={'was_impossible': False}),
#  Prediction(uid='286', iid='234', r_ui=3.0, est=4.109966322634813, details={'was_impossible': False}),
#  Prediction(uid='864', iid='561', r_ui=4.0, est=3.378469069726891, details={'was_impossible': False}),
#  Prediction(uid='57', iid='710', r_ui=3.0, est=3.7007405316723965, details={'was_impossible': False}),
#  Prediction(uid='815', iid='434', r_ui=3.0, est=4.1472534177675495, details={'was_impossible': False}),
#  Prediction(uid='167', iid='216', r_ui=4.0, est=3.869631779880642, details={'was_impossible': False}),
#  Prediction(uid='774', iid='178', r_ui=4.0, est=2.922880233143497, details={'was_impossible': False}),
#  Prediction(uid='44', iid='56', r_ui=2.0, est=3.500763093277786, details={'was_impossible': False}),
#  Prediction(uid='723', iid='164', r_ui=4.0, est=3.212705597926594, details={'was_impossible': False}),
#  Prediction(uid='6', iid='59', r_ui=5.0, est=3.8525363926775094, details={'was_impossible': False}),
#  Prediction(uid='788', iid='70', r_ui=4.0, est=3.593667547565768, details={'was_impossible': False}),
#  Prediction(uid='178', iid='655', r_ui=4.0, est=3.8712948975876316, details={'was_impossible': False}),
#  Prediction(uid='311', iid='39', r_ui=4.0, est=3.220159232494306, details={'was_impossible': False}),
#  Prediction(uid='696', iid='313', r_ui=3.0, est=4.512226801034416, details={'was_impossible': False}),
#  Prediction(uid='328', iid='405', r_ui=4.0, est=3.4304579444779506, details={'was_impossible': False}),
#  Prediction(uid='60', iid='659', r_ui=4.0, est=4.47725867847595, details={'was_impossible': False}),
#  Prediction(uid='619', iid='346', r_ui=3.0, est=3.4661660442270694, details={'was_impossible': False}),
#  Prediction(uid='416', iid='257', r_ui=3.0, est=4.12307906585971, details={'was_impossible': False}),
#  Prediction(uid='429', iid='21', r_ui=2.0, est=3.0357842982469685, details={'was_impossible': False}),
#  Prediction(uid='832', iid='471', r_ui=4.0, est=3.2688547904320737, details={'was_impossible': False}),
#  Prediction(uid='823', iid='217', r_ui=3.0, est=3.271765416465797, details={'was_impossible': False}),
#  Prediction(uid='896', iid='1672', r_ui=2.0, est=2.741847336554443, details={'was_impossible': False}),
#  Prediction(uid='661', iid='175', r_ui=2.0, est=3.6550198895551405, details={'was_impossible': False}),
#  Prediction(uid='246', iid='1052', r_ui=1.0, est=2.311658797481309, details={'was_impossible': False}),
#  Prediction(uid='496', iid='727', r_ui=5.0, est=2.682037263746532, details={'was_impossible': False}),
#  Prediction(uid='91', iid='612', r_ui=4.0, est=4.033808568327873, details={'was_impossible': False}),
#  Prediction(uid='751', iid='428', r_ui=4.0, est=3.517898372927154, details={'was_impossible': False}),
#  Prediction(uid='897', iid='826', r_ui=4.0, est=2.729168864974092, details={'was_impossible': False}),
#  Prediction(uid='551', iid='475', r_ui=5.0, est=4.317033139606953, details={'was_impossible': False}),
#  Prediction(uid='265', iid='15', r_ui=3.0, est=4.093602283931955, details={'was_impossible': False}),
#  Prediction(uid='550', iid='255', r_ui=3.0, est=3.5957672815995414, details={'was_impossible': False}),
#  Prediction(uid='727', iid='89', r_ui=5.0, est=3.6823797370997045, details={'was_impossible': False}),
#  Prediction(uid='246', iid='930', r_ui=2.0, est=2.4871714245055276, details={'was_impossible': False}),
#  Prediction(uid='82', iid='218', r_ui=3.0, est=3.195709624155861, details={'was_impossible': False}),
#  Prediction(uid='452', iid='659', r_ui=4.0, est=3.981478283299713, details={'was_impossible': False}),
#  Prediction(uid='365', iid='25', r_ui=4.0, est=3.3560301170403672, details={'was_impossible': False}),
#  Prediction(uid='941', iid='993', r_ui=4.0, est=3.8236209854493497, details={'was_impossible': False}),
#  Prediction(uid='474', iid='234', r_ui=5.0, est=4.247645404242456, details={'was_impossible': False}),
#  Prediction(uid='650', iid='432', r_ui=4.0, est=3.1521387169693575, details={'was_impossible': False}),
#  Prediction(uid='269', iid='476', r_ui=1.0, est=1.6032809247300044, details={'was_impossible': False}),
#  Prediction(uid='561', iid='1024', r_ui=3.0, est=3.100836770800886, details={'was_impossible': False}),
#  Prediction(uid='753', iid='484', r_ui=5.0, est=3.8047803739007655, details={'was_impossible': False}),
#  Prediction(uid='653', iid='87', r_ui=4.0, est=3.4956928060551533, details={'was_impossible': False}),
#  Prediction(uid='766', iid='965', r_ui=3.0, est=3.053545737046986, details={'was_impossible': False}),
#  Prediction(uid='862', iid='210', r_ui=4.0, est=4.600209135637542, details={'was_impossible': False}),
#  Prediction(uid='393', iid='271', r_ui=3.0, est=2.952332833218165, details={'was_impossible': False}),
#  Prediction(uid='406', iid='503', r_ui=3.0, est=3.5590087610251135, details={'was_impossible': False}),
#  Prediction(uid='618', iid='790', r_ui=3.0, est=2.4441617338993287, details={'was_impossible': False}),
#  Prediction(uid='222', iid='162', r_ui=2.0, est=3.260802419195499, details={'was_impossible': False}),
#  Prediction(uid='374', iid='68', r_ui=1.0, est=3.5298101276342218, details={'was_impossible': False}),
#  Prediction(uid='889', iid='686', r_ui=3.0, est=3.5161096528983973, details={'was_impossible': False}),
#  Prediction(uid='426', iid='653', r_ui=4.0, est=3.7575845952509512, details={'was_impossible': False}),
#  Prediction(uid='405', iid='627', r_ui=1.0, est=2.130291514057813, details={'was_impossible': False}),
#  Prediction(uid='881', iid='192', r_ui=5.0, est=4.033754331111374, details={'was_impossible': False}),
#  Prediction(uid='885', iid='356', r_ui=3.0, est=3.3767004119873767, details={'was_impossible': False}),
#  Prediction(uid='817', iid='289', r_ui=2.0, est=2.604961524676629, details={'was_impossible': False}),
#  Prediction(uid='455', iid='191', r_ui=5.0, est=3.9500623659648086, details={'was_impossible': False}),
#  Prediction(uid='537', iid='455', r_ui=1.0, est=2.7607516448299174, details={'was_impossible': False}),
#  Prediction(uid='99', iid='315', r_ui=4.0, est=4.162620125491936, details={'was_impossible': False}),
#  Prediction(uid='314', iid='693', r_ui=3.0, est=4.0866026253439385, details={'was_impossible': False}),
#  Prediction(uid='659', iid='62', r_ui=4.0, est=3.0522561072173455, details={'was_impossible': False}),
#  Prediction(uid='822', iid='333', r_ui=4.0, est=3.1314793771066607, details={'was_impossible': False}),
#  Prediction(uid='886', iid='959', r_ui=3.0, est=3.3329783676514384, details={'was_impossible': False}),
#  Prediction(uid='638', iid='222', r_ui=4.0, est=3.4780549144379505, details={'was_impossible': False}),
#  Prediction(uid='617', iid='497', r_ui=3.0, est=3.1184677672841676, details={'was_impossible': False}),
#  Prediction(uid='484', iid='70', r_ui=5.0, est=3.9482160376336597, details={'was_impossible': False}),
#  Prediction(uid='785', iid='294', r_ui=4.0, est=3.1756683892140285, details={'was_impossible': False}),
#  Prediction(uid='870', iid='856', r_ui=3.0, est=3.6160483041924416, details={'was_impossible': False}),
#  Prediction(uid='918', iid='208', r_ui=3.0, est=3.6350407503034146, details={'was_impossible': False}),
#  Prediction(uid='472', iid='385', r_ui=5.0, est=4.316671188573329, details={'was_impossible': False}),
#  Prediction(uid='532', iid='204', r_ui=5.0, est=4.945068247533283, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1025', r_ui=1.0, est=1.3227458855956342, details={'was_impossible': False}),
#  Prediction(uid='665', iid='472', r_ui=3.0, est=3.285806811112527, details={'was_impossible': False}),
#  Prediction(uid='188', iid='717', r_ui=4.0, est=2.6852611489792086, details={'was_impossible': False}),
#  Prediction(uid='417', iid='203', r_ui=4.0, est=3.6348775685460386, details={'was_impossible': False}),
#  Prediction(uid='468', iid='39', r_ui=3.0, est=3.217138808176146, details={'was_impossible': False}),
#  Prediction(uid='180', iid='56', r_ui=5.0, est=4.276344807205891, details={'was_impossible': False}),
#  Prediction(uid='766', iid='648', r_ui=3.0, est=3.38386632398979, details={'was_impossible': False}),
#  Prediction(uid='295', iid='73', r_ui=4.0, est=4.098244859989034, details={'was_impossible': False}),
#  Prediction(uid='130', iid='366', r_ui=5.0, est=4.13968717060048, details={'was_impossible': False}),
#  Prediction(uid='16', iid='208', r_ui=5.0, est=4.476300550919145, details={'was_impossible': False}),
#  ...]

# %%
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.9349

# %%
cross_validate(algo, data, measures=['RMSE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9391  0.9324  0.9309  0.9426  0.9360  0.9362  0.0043
# Fit time          4.99    4.73    4.59    4.88    4.58    4.75    0.16
# Test time         0.18    0.18    0.18    0.15    0.20    0.18    0.02
# {'test_rmse': array([0.93911327, 0.93240662, 0.93087695, 0.94259758, 0.9359627 ]),
#  'fit_time': (4.9889631271362305,
#   4.734012126922607,
#   4.586277961730957,
#   4.884279251098633,
#   4.576915979385376),
#  'test_time': (0.17507195472717285,
#   0.1829395294189453,
#   0.18334484100341797,
#   0.14960074424743652,
#   0.1994335651397705)}

# %% [markdown]
# ### 4. Prediction

# %%
uid = '585' # raw user id (as in the ratings file). They are **strings**!
iid = '1344'  # raw item id (as in the ratings file). They are **strings**!


# get a prediction for specific users and items.
pred = algo.predict(uid, iid, r_ui =3, verbose=True)
# Out:
# user: 585        item: 1344       r_ui = 3.00   est = 3.51   {'was_impossible': False}
